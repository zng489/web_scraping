# %%
#Importing packages
from selenium import webdriver
import pandas as pd

# %%
chromedriver = 'C:/Users/Yuan/Desktop/chromedriver_win32/chromedriver'

# %%
driver = webdriver.Chrome(chromedriver)

# %%
driver.get("https://www.nintendo.com/")

# %%
print(driver.page_source)
# Out:
# <html lang="en-US" class="js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths no-isios flexboxlegacy supports alps-os-windows" data-triggered="true"><head><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style>
#     <meta charset="UTF-8">
#     <title>
#     Nintendo - Official Site - Video Game Consoles, Games
# </title>
#
# ...

# %%
driver.title
# Out:
# 'Nintendo - Official Site - Video Game Consoles, Games'

# %%
driver.current_url
# Out:
# 'https://www.nintendo.com/'

# %% [markdown]
# # -------------------------------------------------------------------

# %%
user_message = driver.find_elements_by_xpath('//*[@id="at-track-click-15943223769417185"]/recommendation-slider/game-tile[1]/h3')[0]

# %%
user_message.text
# Out:
# 'Super Mario™ 3D All-Stars'

# %% [markdown]
# # # -------------------------------------------------------------------

# %%
//*[@id="at-track-click-15943223769417185"]/recommendation-slider//div/div[1]/div

# %%
q = driver.find_elements_by_xpath('//*[@id="at-track-click-15943223769417185"]/recommendation-slider//div/div[1]/div')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-3389b07c31ea> in <module>
# ----> 1 q = driver.find_elements_by_xpath('//*[@id="at-track-click-15943223769417185"]/recommendation-slider//div/div[1]/div')[0]
#
# IndexError: list index out of range

# %%
q
# Out:
# []

# %%
//*[@id="at-track-click-15943223769417185"]/recommendation-slider//div

# %%
driver.find_elements_by_xpath('//*[@id="at-track-click-15943223769417185"]/recommendation-slider//div')
# Out:
# []

# %%
driver.find_element_by_class_name("h2 no-margin")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-37-7102c309be94> in <module>
# ----> 1 driver.find_element_by_class_name("h2 no-margin")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ...

# %%
h1 = driver.find_element_by_name('div')
h1 = driver.find_element_by_class_name('titles')
h1 = driver.find_element_by_xpath('//div')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-20-2e6550c0c160> in <module>
# ----> 1 h1 = driver.find_element_by_name('div')
#       2 h1 = driver.find_element_by_class_name('titles')
#       3 h1 = driver.find_element_by_xpath('//div')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_name(self, name)
#     494             element = driver.find_element_by_name('foo')
#     495         """
# --> 496         return self.find_element(by=By.NAME, value=name)
#     497
#     498     def find_elements_by_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
# ...
