# %%
import requests

# %%
import bs4

# %%
result = requests.get('https://pt.wikipedia.org/wiki/China')

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '\n<!DOCTYPE html>\n<html class="client-nojs" lang="pt" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>China – Wikipédia, a enciclopédia livre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"],"wgRequestId":"31cf6230-c6a4-442c-92b9-665c59cc8d28","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"China","wgTitle":"China","wgCurRevisionId":58582054,"wgRevisionId":58582054,"wgArticleId":522,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["!CS1 inglês-fontes em língua (en)","!Páginas que usam referências com parâmetros obsoletas","!CS1 manut: Nomes múltiplos: lista de autores","!Artigos c
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="pt">
# <head>
# <meta charset="utf-8"/>
# <title>China – Wikipédia, a enciclopédia livre</title>
# ...

# %%
soup.select('title')
# Out:
# [<title>China – Wikipédia, a enciclopédia livre</title>]

# %%
soup.select('title')[0]
# Out:
# <title>China – Wikipédia, a enciclopédia livre</title>

# %%
soup.select('title')[0].getText()
# Out:
# 'China – Wikipédia, a enciclopédia livre'

# %% [markdown]
# ## Other Example

# %%
result1 = requests.get('https://pt.wikipedia.org/wiki/Scrapy')

# %%
soup1 = bs4.BeautifulSoup(result1.text,'lxml')

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="pt">
# <head>
# <meta charset="utf-8"/>
# <title>Scrapy – Wikipédia, a enciclopédia livre</title>
# ...

# %%
soup1.select('.mw-redirect')
# Out:
# [<a class="mw-redirect" href="/wiki/Scrapie" title="Scrapie">Scrapie</a>,
#  <a class="mw-redirect" href="/wiki/Web_crawler" title="Web crawler">Web crawler</a>,
#  <a class="mw-redirect" href="/wiki/BSD_License" title="BSD License">BSD License</a>,
#  <a class="mw-redirect" href="/wiki/Web_crawler" title="Web crawler">web-crawling</a>,
#  <a class="mw-redirect" href="/wiki/Application_programming_interface" title="Application programming interface">APIs</a>,
#  <a class="mw-redirect" href="/wiki/Web_crawler" title="Web crawler">web crawler</a>,
#  <a class="mw-redirect" href="/wiki/Django_(web_framework)" title="Django (web framework)">Django</a>,
#  <a class="mw-redirect" href="/wiki/Wikip%C3%A9dia:Sobre" title="Wikipédia:Sobre">Sobre a Wikipédia</a>]

# %%
first_item = soup1.select('.mw-redirect')[0]

# %%
first_item
# Out:
# <a class="mw-redirect" href="/wiki/Scrapie" title="Scrapie">Scrapie</a>

# %%
first_item.text
# Out:
# 'Scrapie'

# %% [markdown]
# # Grabbing Class and Image and For item in

# %%
first_item = soup1.select('.mw-redirect')[0].getText()

# %%
first_item
# Out:
# 'Scrapie'

# %%
for item in soup1.select('.mw-redirect'):
    print(item.text)
# Out:
# Scrapie
# Web crawler
# BSD License
# web-crawling
# APIs
# web crawler
# Django
# Sobre a Wikipédia
