# %%
import requests
from bs4 import BeautifulSoup

# %%
################################################################################

def extract(page):   # ---> extract(0)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}
    url = f"https://www.indeed.......start={page}"
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    print(r.status_code)
    return soup

################################################################################
    
def transform(soup):
    divs = soup.find_all('div',class_ ='jobsearch-SerpJobCard')
    for item in divs:
        title = item.find('a').text.strip()
        company = item.find('span',class_ = 'company').text.strip()
        
        try:
            salary = item.find('span', class_ = 'salaryText').text.strip()      
        except:
            salary = ''
            
        summary = item.find('div', {'class':'summary'}).text.strip()
        
        job = {
            'title':title,
            'company':company,
            'salary':salary,
            'summary':summary
        }
        
        joblist.append(job)
        
################################################################################
        
joblist = []

for i in range(0,40,10):
    print(f'Getting page,{i}')
    c = extract(0)
    transform(c)   # ---> transform(extract(0))
    
################################################################################ 

df = pd.DataFrame(joblist)
print(df.head())

df.to_csv('jobs.csv')
    
    
print(len(joblist))

################################################################################

# %%
import pandas as pd

# %%
df = pd.read_csv('indeed.csv')

# %%
df
# Out:
#        Unnamed: 0    ID                             TAG  \
# 0               0     1                             Url
# 1               1     1                   Codigo criado
# 2               2     1                         Empresa
# 3               3     1                       Nome Vaga
# 4               4     1                      Localidade
# 5               5     1                  Data publicada
# 6               6     1                         salario
# 7               7     1                          Regime
# 8               8     1             Data do WebScraping
# 9               9     1                           Vagas
# 10             10     1  Conteúdo/Benefícios/Exigências
# 11             11     2                             Url
# 12             12     2                   Codigo criado
# 13             13     2                         Empresa
# 14             14     2                       Nome Vaga
# 15             15     2                      Localidade
# 16             16     2                  Data publicada
# 17             17     2                         salario
# 18             18     2                          Regime
# 19             19     2             Data do WebScraping
# 20             20     2                           Vagas
# 21             21     2  Conteúdo/Benefícios/Exigências
# 22             22     3                             Url
# 23             23     3                   Codigo criado
# 24             24     3                         Empresa
# 25             25     3                       Nome Vaga
# 26             26     3                      Localidade
# 27             27     3                  Data publicada
# 28             28     3                         salario
# 29             29     3                          Regime
# ...           ...   ...                             ...
# 19231       19231  1749                       Nome Vaga
# 19232       19232  1749                      Localidade
# 19233       19233  1749                  Data publicada
# 19234       19234  1749                         salario
# 19235       19235  1749                          Regime
# 19236       19236  1749             Data do WebScraping
# 19237       19237  1749                           Vagas
# 19238       19238  1749  Conteúdo/Benefícios/Exigências
# 19239       19239  1750                             Url
# 19240       19240  1750                   Codigo criado
# 19241       19241  1750                         Empresa
# 19242       19242  1750                       Nome Vaga
# 19243       19243  1750                      Localidade
# 19244       19244  1750                  Data publicada
# 19245       19245  1750                         salario
# 19246       19246  1750                          Regime
# 19247       19247  1750             Data do WebScraping
# 19248       19248  1750                           Vagas
# 19249       19249  1750  Conteúdo/Benefícios/Exigências
# 19250       19250  1751                             Url
# 19251       19251  1751                   Codigo criado
# 19252       19252  1751                         Empresa
# 19253       19253  1751                       Nome Vaga
# 19254       19254  1751                      Localidade
# 19255       19255  1751                  Data publicada
# 19256       19256  1751                         salario
# 19257       19257  1751                          Regime
# 19258       19258  1751             Data do WebScraping
# 19259       19259  1751                           Vagas
# 19260       19260  1751  Conteúdo/Benefícios/Exigências
#
#                                                    TEXTO   TAMANHO  NEGRITO  \
# 0      https://br.indeed.com/cmp/Maxim-E-Hailing-Service    Padrão        0
# 1                           /cmp/Maxim-E-Hailing-Service    Padrão        0
# 2                                          Maxim Company  h1(18px)        1
# 3                             Gerente Administrativonova      15px        0
# 4                                             Cuiabá, MT      16px        0
# 5                                        Recém publicada      15px        0
# 6                                             a combinar      13px        0
# 7                                                      -      15px        0
# 8                                             03/05/2021      15px        0
# 9                                                      -      13px        0
# 10                                                     -      13px        0
# 11     https://br.indeed.com/rc/clk?jk=d6340519cca565...    Padrão        0
# 12     /rc/clk?jk=d6340519cca5653c&fccid=92d9703d1d0a...    Padrão        0
# 13                                                Klabin  h1(18px)        1
# 14                                      Almoxarife Inova      15px        0
# 15                                                Brasil      16px        0
# 16                                       Recém publicada      15px        0
# 17                                            a combinar      13px        0
# 18                                                     -      15px        0
# 19                                            03/05/2021      15px        0
# 20                                                     -      13px        0
# 21     . Local: Monte Alegre (Telêmaco Borba / PR) Ár...      13px        0
# 22     https://br.indeed.com/rc/clk?jk=7d84d7eb06028b...    Padrão        0
# 23     /rc/clk?jk=7d84d7eb06028bdb&fccid=dd616958bd9d...    Padrão        0
# 24                                                     -  h1(18px)        1
# 25                  Auxiliar Financeiro - Taguatinganova      15px        0
# 26                                          Brasília, DF      16px        0
# 27                                       Recém publicada      15px        0
# 28                                            a combinar      13px        0
# 29                                                     -      15px        0
# ...                                                  ...       ...      ...
# 19231                        Analista Contábil Plenonova      15px        0
# 19232                                 Belo Horizonte, MG      16px        0
# 19233                                    Recém publicada      15px        0
# 19234                            2.500 -   3.000 por mês      13px        0
# 19235                                        Home office      15px        0
# 19236                                         03/05/2021      15px        0
# 19237                                                  -      13px        0
# 19238                                                  -      13px        0
# 19239  https://br.indeed.com/pagead/clk?mo=r&ad=-6NYl...    Padrão        0
# 19240  /pagead/clk?mo=r&ad=-6NYlbfkN0ABu8p8DQmF4OKQHm...    Padrão        0
# 19241                        iFood - PÁGINA DE CARREIRAS  h1(18px)        1
# 19242       Executivo Vendas Externa III - Groceriesnova      15px        0
# 19243                                       Brasília, DF      16px        0
# 19244                                          há 4 dias      15px        0
# 19245                                         a combinar      13px        0
# 19246                                        Home office      15px        0
# 19247                                         03/05/2021      15px        0
# 19248                                                  -      13px        0
# 19249  No iFood, acreditamos na força da diversidade ...      13px        0
# 19250  https://br.indeed.com/pagead/clk?mo=r&ad=-6NYl...    Padrão        0
# 19251  /pagead/clk?mo=r&ad=-6NYlbfkN0AUD9hI6c9pHBCiq4...    Padrão        0
# 19252                              Leilões Investimentos  h1(18px)        1
# 19253         Secretária / Assistente Administrativonova      15px        0
# 19254                                       Barretos, SP      16px        0
# 19255                                          há 4 dias      15px        0
# 19256                                      1.500 por mês      13px        0
# 19257                                                  -      15px        0
# 19258                                         03/05/2021      15px        0
# 19259                                                  -      13px        0
# 19260                                                  -      13px        0
#
#          COR
# 0      Preta
# 1      Preta
# 2      Preta
# 3      Preta
# 4      Preta
# 5      Preta
# 6      Preta
# 7      Preta
# 8      Preta
# 9      Preta
# 10     Preta
# 11     Preta
# 12     Preta
# 13     Preta
# 14     Preta
# 15     Preta
# 16     Preta
# 17     Preta
# 18     Preta
# 19     Preta
# 20     Preta
# 21     Preta
# 22     Preta
# 23     Preta
# 24     Preta
# 25     Preta
# 26     Preta
# 27     Preta
# 28     Preta
# 29     Preta
# ...      ...
# 19231  Preta
# 19232  Preta
# 19233  Preta
# 19234  Preta
# 19235  Preta
# 19236  Preta
# 19237  Preta
# 19238  Preta
# 19239  Preta
# 19240  Preta
# 19241  Preta
# 19242  Preta
# 19243  Preta
# 19244  Preta
# 19245  Preta
# 19246  Preta
# 19247  Preta
# 19248  Preta
# 19249  Preta
# 19250  Preta
# 19251  Preta
# 19252  Preta
# 19253  Preta
# 19254  Preta
# 19255  Preta
# 19256  Preta
# 19257  Preta
# 19258  Preta
# 19259  Preta
# 19260  Preta
#
# [19261 rows x 7 columns]
