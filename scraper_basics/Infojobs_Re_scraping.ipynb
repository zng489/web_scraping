# %%
import pandas as pd

# %%
df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)

# %%
df.head(5)
# Out:
#    id                                                url   codigo  \
# 0   0  https://www.infojobs.com.br/vaga-de-operador-c...  7129630
# 1   1  https://www.infojobs.com.br/vaga-de-atendente-...  7207593
# 2   2  https://www.infojobs.com.br/vaga-de-vue-js-tec...  7207597
# 3   3  https://www.infojobs.com.br/vaga-de-atendiment...  7206929
# 4   4  https://www.infojobs.com.br/vaga-de-vue-js-tec...  7207595
#
#                                   profissao                 salario  \
# 0   Operador De Call Center Ativo De Vendas              A combinar
# 1                       Atendente De Vendas   1.500,00 a  1.800,00
# 2           Vue.Js Tech Lead - Remote Work.              A combinar
# 3                          Atendimento - Bh               1.135,00
# 4           Vue.Js Tech Lead - Remote Work.              A combinar
#
#                                     vagas           localidade  \
# 0    Mais de 50 candidaturas para a vaga         Sao Paulo, SP
# 1             0 candidaturas para a vaga         Sao Paulo, SP
# 2             0 candidaturas para a vaga         Fortaleza, CE
# 3             0 candidaturas para a vaga    Belo Horizonte, MG
# 4              1 candidatura para a vaga            Recife, PE
#
#    data publicada        regime  \
# 0  Mais de um mes        Outros
# 1  Mais de um mes  Efetivo  CLT
# 2  Mais de um mes  Efetivo  CLT
# 3  Mais de um mes  Efetivo  CLT
# 4  Mais de um mes  Efetivo  CLT
#
#                                             conteudo           horario  \
# 0  Area e especializacao profissional: Telemarket...  Periodo Integral
# 1  Area e especializacao profissional: Comercial,...  Periodo Integral
# 2  Area e especializacao profissional: Informatic...  Periodo Integral
# 3  Area e especializacao profissional: Comercial,...  Periodo Integral
# 4  Area e especializacao profissional: Informatic...  Periodo Integral
#
#                          empresa data do scraping adicional beneficios
# 0  Empresa com nome confidencial       29/04/2021      None       None
# 1                       CESARMAQ       29/04/2021      None       None
# 2                      BairesDev       29/04/2021      None       None
# 3              VALLOR BENEFICIOS       29/04/2021      None       None
# 4                      BairesDev       29/04/2021      None       None

# %%
list_url = df['url'].to_list()

# %%
list_url
# Out:
# ['https://www.infojobs.com.br/vaga-de-operador-call-center-ativo-vendas-em-sao-paulo__7129630.aspx',
#  'https://www.infojobs.com.br/vaga-de-atendente-vendas-em-sao-paulo__7207593.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-ceara__7207597.aspx',
#  'https://www.infojobs.com.br/vaga-de-atendimento-bh-em-minas-gerais__7206929.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-pernambuco__7207595.aspx',
#  'https://www.infojobs.com.br/vaga-de-consultor-vendas-em-pernambuco__7206056.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-parana__7207596.aspx',
#  'https://www.infojobs.com.br/vaga-de-instrutor-solda-em-parana__7207541.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-sao-paulo__7207599.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-manutencao-campinas-em-sao-paulo__7207543.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-distrito-federal__7207600.aspx',
#  'https://www.infojobs.com.br/vaga-de-comprador-construcao-civil-em-rio-grande-do-sul__7207535.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-goias__7207598.aspx',
#  'https://www.infojobs.com.br/vaga-de-advogado-em-rio-grande-do-sul__7207532.aspx',
#  'https://www.infojobs.com.br/vaga-de-promotor-merchandising-canal-farma-carro-zona-oeste-em-sao-paulo__7207594.aspx',
#  'https://www.infojobs.com.br/vaga-de-fiscal-obras-construtora-em-rio-grande-do-sul__7207523.aspx',
#  'https://www.infojobs.com.br/vaga-de-operador-loja-estoquista-pcd-big-cristal-porto-algre-em-rio-grande-do-sul__7207591.aspx',
#  'https://www.infojobs.com.br/vaga-de-manipulador-farmacia-em-rio-janeiro__7061406.aspx',
#  'https://www.infojobs.com.br/vaga-de-operador-logistica-em-bahia__7207592.aspx',
#  'https://www.infojobs.com.br/vaga-de-supervisor
aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-estoque-barueri-em-sao-paulo__7207135.aspx',
#  'https://www.infojobs.com.br/vaga-de-amostrador-em-sao-paulo__6992530.aspx',
#  'https://www.infojobs.com.br/vaga-de-operador-loja-jaguare-em-sao-paulo__7207132.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-compras-em-sao-paulo__7170109.aspx',
#  'https://www.infojobs.com.br/vaga-de-porteiro-tatuape-z-l-em-sao-paulo__7207130.aspx',
#  'https://www.infojobs.com.br/vaga-de-engenheiro-processos-em-sao-paulo__7204865.aspx',
#  'https://www.infojobs.com.br/vaga-de-aux-operacional-logistica-em-sao-paulo__7207128.aspx',
#  'https://www.infojobs.com.br/vaga-de-consultor-comercial-clt-vt-comissoes-premiacoes-em-parana__7136552.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-administrativo-financeiro-em-rio-janeiro__7207127.aspx',
#  'https://www.infojobs.com.br/vaga-de-analista-licitacao-em-rio-grande-do-sul__7170085.aspx',
#  'https://www.infojobs.com.br/vaga-de-supervisor-loja-loja-camaqua-em-rio-grande-do-sul__7207126.aspx',
#  'https://www.infojobs.com.br/vaga-de-analista-licitacao-em-rio-grande-do-sul__7170087.aspx',
#  'https://www.infojobs.com.br/vaga-de-coordenador-pmo-expansao-em-sao-paulo__7207125.aspx',
#  'https://www.infojobs.com.br/vaga-de-costureira-overloquista-em-sao-paulo__7106455.aspx',
#  'https://www.infojobs.com.br/vaga-de-aux-logistica-wms-coletor-em-sao-paulo__7207122.aspx',
#  ...]

# %%
type(list_url)
# Out:
# list

# %%
###############################################################################

# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
import csv
from random import randint
from datetime import date
from time import sleep

from selenium import webdriver   # for webdriver
from selenium.webdriver.support.ui import WebDriverWait  # for implicit and explict waits
from selenium.webdriver.chrome.options import Options  # for suppressing the browse
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import datetime
import time
import csv

from bs4 import BeautifulSoup
import requests
import csv

# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
import csv
from random import randint
from datetime import date
from time import sleep

from selenium import webdriver   # for webdriver
from selenium.webdriver.support.ui import WebDriverWait  # for implicit and explict waits
from selenium.webdriver.chrome.options import Options  # for suppressing the browse
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import datetime
import time
import csv

from bs4 import BeautifulSoup
import requests
import csv


class Infojobs():

    #headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
    #df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    #list = df['url'].to_list()
    
    def __init__(self,list_url):
        self.baseurl = list_url

        #for every_url in list_url:
            #print(every_url)
            #cada_link = every_url
        #return None #or __init__() should return None, not 'str'
        
    def url_chosen(self,pages):
        
        
        
        
        
        dados_infojobs = []

        headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
        try:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            soup = BeautifulSoup(re, "html.parser")
            time.sleep(2)    
            r = requests.get(cada_link,allow_redirects=False)
        except:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            soup = BeautifulSoup(re, "html.parser")
            time.sleep(2)
            r = requests.get(cada_link,allow_redirects=False)
                             
        if r.status_code == 200:
            url = cada_link
            
            try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
            except:
                conteudo = 'None'
                    
            try:   
                exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
            except:
                exigencias = 'None'
                
            try:
                beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
            except:
                beneficios = 'None'

                
            dados = {'conteudo':conteudo,
                    'exigencias':exigencias,
                    'beneficios':beneficios,
                    'url':url}
            
            dados_infojobs.append(dados)
            
            df = pd.DataFrame(dados_infojobs)
            df.to_csv('dados_infojobs.csv')

        else:
            print('url nao existe mais')
            
        return cada_link
                             
def main():
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    Infojobs(df_list_url) # list_url = df_list_url
                             
if __name__ == "__main__":
    main()
# Out:
#   File "<ipython-input-97-072c21af6c6f>", line 27
#     soup = BeautifulSoup(re, "html.parser")
#        ^
# SyntaxError: invalid syntax

# %%
class Infojobs():                 ---|
                                     | -------> x = Infojobs("https://www.infojobs.com.br") = every_url
def __init__(self,every_url):     ---| 
    
def url_chosen(self,every_url):   ---| -------> x.url_chosen(pages)
    
    
for pages in range(1,2):
    pages = 1
    pages = 2
# Out:
# "['https://www.infojobs.com.br/vaga-de-assistente-logistica-comex-em-santa-catarina__7095563.aspx', 'https://www.infojobs.com.br/vaga-de-assistente-logistica-comex-em-santa-catarina__7095563.aspx']"

# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
import csv
from random import randint
from datetime import date
from time import sleep

from selenium import webdriver   # for webdriver
from selenium.webdriver.support.ui import WebDriverWait  # for implicit and explict waits
from selenium.webdriver.chrome.options import Options  # for suppressing the browse
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import datetime
import time
import csv

from bs4 import BeautifulSoup
import requests
import csv

# %%
def re_scraping():
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    for link in df_list_url:
        link = x 
    return x

def url_chosen(x):
    x = cada_link
    print(cada_link)
    dados_infojobs = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
    try:
        re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
        soup = BeautifulSoup(re, "html.parser")
        time.sleep(2)    
        r = requests.get(cada_link,allow_redirects=False)
    except:
        re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
        soup = BeautifulSoup(re, "html.parser")
        time.sleep(2)
        r = requests.get(cada_link,allow_redirects=False)
                             
        if r.status_code == 200:
            url = cada_link
            
            try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
            except:
                conteudo = 'None'
                
            try:   
                exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
            except:
                exigencias = 'None'
            
            try:
                beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
            except:
                beneficios = 'None'
            
            dados = {'conteudo':conteudo,
                'exigencias':exigencias,
                'beneficios':beneficios,
                'url':url}
        
            dados_infojobs.append(dados)
        
            df = pd.DataFrame(dados_infojobs)
            df.to_csv('dados_infojobs.csv')

        else:
            print('url nao existe mais')
            
    return cada_link
                            
if __name__ == "__main__":
    re_scraping() #apenas link
    #url_chosen()

# %%
def re_scraping():
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    for link in df_list_url:
        link = x
        print(x)
    return x

# %%
def re_scraping():
    
    dados_infojobs = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    for link in df_list_url:
        cada_link = link
        
        time.sleep(2) 
        
        try:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            time.sleep(2)    
            r = requests.get(cada_link,allow_redirects=False)
            soup = BeautifulSoup(re, "html.parser")
        except:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            time.sleep(2)
            r = requests.get(cada_link,allow_redirects=False)
            soup = BeautifulSoup(re, "html.parser")
                             
            if r.status_code == 200:
                print(cada_link)
            
                try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                    conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
                except:
                    conteudo = 'None'
                
                try:   
                    exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    exigencias = 'None'
            
                try:
                    beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    beneficios = 'None'
            
                dados = {'conteudo':conteudo,
                    'exigencias':exigencias,
                    'beneficios':beneficios,
                    'url':url}
        
                dados_infojobs.append(dados)
        
                df = pd.DataFrame(dados_infojobs)
                df.to_csv('dados_infojobs.csv')

            else:
                print('url nao existe mais')
            
    return cada_link
                            
if __name__ == "__main__":
    re_scraping() #apenas link
    #url_chosen()

# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
import csv
from random import randint
from datetime import date
from time import sleep
import datetime
import time
import csv

from bs4 import BeautifulSoup
import requests
import csv

# %%
df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
df_list_url = df['url'].to_list()
df_list_url
# Out:
# ['https://www.infojobs.com.br/vaga-de-operador-call-center-ativo-vendas-em-sao-paulo__7129630.aspx',
#  'https://www.infojobs.com.br/vaga-de-atendente-vendas-em-sao-paulo__7207593.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-ceara__7207597.aspx',
#  'https://www.infojobs.com.br/vaga-de-atendimento-bh-em-minas-gerais__7206929.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-pernambuco__7207595.aspx',
#  'https://www.infojobs.com.br/vaga-de-consultor-vendas-em-pernambuco__7206056.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-parana__7207596.aspx',
#  'https://www.infojobs.com.br/vaga-de-instrutor-solda-em-parana__7207541.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-sao-paulo__7207599.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-manutencao-campinas-em-sao-paulo__7207543.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-distrito-federal__7207600.aspx',
#  'https://www.infojobs.com.br/vaga-de-comprador-construcao-civil-em-rio-grande-do-sul__7207535.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-goias__7207598.aspx',
#  'https://www.infojobs.com.br/vaga-de-advogado-em-rio-grande-do-sul__7207532.aspx',
#  'https://www.infojobs.com.br/vaga-de-promotor-merchandising-canal-farma-carro-zona-oeste-em-sao-paulo__7207594.aspx',
#  'https://www.infojobs.com.br/vaga-de-fiscal-obras-construtora-em-rio-grande-do-sul__7207523.aspx',
#  'https://www.infojobs.com.br/vaga-de-operador-loja-estoquista-pcd-big-cristal-porto-algre-em-rio-grande-do-sul__7207591.aspx',
#  'https://www.infojobs.com.br/vaga-de-manipulador-farmacia-em-rio-janeiro__7061406.aspx',
#  'https://www.infojobs.com.br/vaga-de-operador-logistica-em-bahia__7207592.aspx',
#  'https://www.infojobs.com.br/vaga-de-supervisor-producao-alimentos-em-sao-paulo__7093655.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-tecnico-telecomunicacoes-em-rio-janeiro__7092494.aspx',
#  'https://www.infojobs.com.br/vaga-de-conferente-mercadorias-zona-norte-em-sao-paulo__7188516.aspx',
#  'https://www.infojobs.com.br/vaga-de-assistente-departamento-pessoal-em-parana__7207508.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-minas-gerais__7207588.aspx',
#  'https://www.infojobs.com.br/vaga-de-vendedor-tecnico-construcao-civil-em-rio-grande-do-sul__7207498.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-sao-paulo__7207586.aspx',
#  'https://www.infojobs.com.br/vaga-de-assistente-departamento-pessoal-em-sao-paulo__7207480.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-bahia__7207587.aspx',
#  'https://www.infojobs.com.br/vaga-de-consultor-vendas-internas-em-minas-gerais__7207431.aspx',
#  'https://www.infojobs.com.br/vaga-de-telemarketing-seg-sexta-ativo-vendas-experiencia-em-sao-paulo__7207590.aspx',
#  'https://www.infojobs.com.br/vaga-de-tecnico-impressoras-suporte-impressao-em-sao-paulo__7093293.aspx',
#  'https://www.infojobs.com.br/vaga-de-vue-js-tech-lead-remote-work-em-rio-janeiro__7207585.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-limpeza
aspx',
#  'https://www.infojobs.com.br/vaga-de-qa-automation-leader-remote-work-em-sao-paulo__7207140.aspx',
#  'https://www.infojobs.com.br/vaga-de-executivo-vendas-transportes-em-sao-paulo__7170129.aspx',
#  'https://www.infojobs.com.br/vaga-de-qa-automation-leader-remote-work-em-bahia__7207141.aspx',
#  'https://www.infojobs.com.br/vaga-de-tecnico-empilhadeiras-iii-sao-paulo-em-sao-paulo__7207137.aspx',
#  'https://www.infojobs.com.br/vaga-de-coordenador-comercial-duque-caxias-em-rio-janeiro__7204888.aspx',
#  'https://www.infojobs.com.br/vaga-de-tecnico-manutencao-pituba-ba-em-bahia__7207136.aspx',
#  'https://www.infojobs.com.br/vaga-de-assistente-fiscal-em-sao-paulo__7096638.aspx',
#  'https://www.infojobs.com.br/vaga-de-telemarketing-vendas-manha-tarde-em-sao-paulo__7207133.aspx',
#  'https://www.infojobs.com.br/vaga-de-tecnico-manutencao-manutencao-em-mato-grosso-do-sul__7201338.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-fiscal-conhecer-bloco-k-contmatic-em-sao-paulo__7170116.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-engenheiro-civil-medidor-em-sao-paulo__7207134.aspx',
#  'https://www.infojobs.com.br/vaga-de-analista-estoque-em-parana__7204878.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-estoque-barueri-em-sao-paulo__7207135.aspx',
#  'https://www.infojobs.com.br/vaga-de-amostrador-em-sao-paulo__6992530.aspx',
#  'https://www.infojobs.com.br/vaga-de-operador-loja-jaguare-em-sao-paulo__7207132.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-compras-em-sao-paulo__7170109.aspx',
#  'https://www.infojobs.com.br/vaga-de-porteiro-tatuape-z-l-em-sao-paulo__7207130.aspx',
#  'https://www.infojobs.com.br/vaga-de-engenheiro-processos-em-sao-paulo__7204865.aspx',
#  'https://www.infojobs.com.br/vaga-de-aux-operacional-logistica-em-sao-paulo__7207128.aspx',
#  'https://www.infojobs.com.br/vaga-de-consultor-comercial-clt-vt-comissoes-premiacoes-em-parana__7136552.aspx',
#  'https://www.infojobs.com.br/vaga-de-auxiliar-administrativo-financeiro-em-rio-janeiro__7207127.aspx',
#  'https://www.infojobs.com.br/vaga-de-analista-licitacao-em-rio-grande-do-sul__7170085.aspx',
#  'https://www.infojobs.com.br/vaga-de-supervisor-loja-loja-camaqua-em-rio-grande-do-sul__7207126.aspx',
#  'https://www.infojobs.com.br/vaga-de-analista-licitacao-em-rio-grande-do-sul__7170087.aspx',
#  'https://www.infojobs.com.br/vaga-de-coordenador-pmo-expansao-em-sao-paulo__7207125.aspx',
#  'https://www.infojobs.com.br/vaga-de-costureira-overloquista-em-sao-paulo__7106455.aspx',
#  'https://www.infojobs.com.br/vaga-de-aux-logistica-wms-coletor-em-sao-paulo__7207122.aspx',
#  ...]

# %%
dados_infojobs = []
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
      
df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
df_list_url = df['url'].to_list()
for link in df_list_url:
    cada_link = link
               
    try:
        re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
        time.sleep(2)    
        r = requests.get(cada_link,allow_redirects=False)
        
    except:
        re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
        time.sleep(2)
        r = requests.get(cada_link,allow_redirects=False)
        
    if r.status_code == 200:
        print(link)
        
        soup = BeautifulSoup(re, "html.parser")
        
        try:
            #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
            conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
            print(conteudo)
        except:
            conteudo = 'None'
            
    else:
        print('url nao existe mais')
# Out:
# url nao existe mais
# url nao existe mais
# url nao existe mais
# https://www.infojobs.com.br/vaga-de
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-operador-logistica-em-bahia__7207592.aspx
# Área e especialização profissional: Logística - LogísticaNível hierárquico: OperacionalNúmero de vagas: 5Local de trabalho: Simões Filho, BAArmazenar e movimentar os produtos de acordo com as tarefas de movimentação física; Fazer o carregamento dos veículos com auxílio da transpaleteira, respeitando as normas de segurança; Auxiliar na contagem dos produtos; Benefícios: -. Assistência médica -. Assistência odontológica -. segur -. Vale-transporte -. Refeição no local
# https://www.infojobs.com.br/vaga-de-supervisor-producao-alimentos-em-sao-paulo__7093655.aspx
# Área e especialização profissional: Alimentação / Gastronomia - GastronomiaNível hierárquico: SupervisorLocal de trabalho: São Paulo, SPAtuação como supervisora de produção em cozinha industrial, com planejamento da produção, controle de estoque, qualidade de produtos e serviços no segmento alimentar.Atividades:Organização; Realização de pedidos de compra, Contato com os fornecedores; Controle de estoques; Planejamento da produção; Administração e supervisão da equipe, operacional, Higiênico e sanitário.
# https://www.infojobs.com.br/vaga-de-auxiliar-tecnico-telecomunicacoes-em-rio-janeiro__7092494.aspx
# Área e especialização profissional: Informática, TI, Telecomunicações - TelecomunicaçõesNível hierárquico: AuxiliarLocal de trabalho: Rio de Janeiro, RJLevantar dados em Sistemas Corporativos, próprio ou do Cliente;Elaborar desenhos e Cadastro de Projetos de Rede de Telecomunicações, em AUTOCAD e SISTEMAS do CLIENTE;Atualizar dados em Sistemas próprios e do Cliente;Verificar documentação técnica dos projetos de Rede;Cadastramento de projetos em Sistemas GEOREFERENCIADOS;Vistoria de Campo para levantamento de Redes  e Infraestruturas de Telecomunicação, tanto externo quanto em ambiente do Cliente.Leitura / Identificação de Projetos para realização de Atividades de Quantificação de Materiais e Serviço;Elaborar Croqui / Esquemáticos de Rede Interna
# https://www.infojobs.com.br/vaga-de-conferente-mercadorias-zona-norte-em-sao-paulo__7188516.aspx
# Área e especialização profissional: Logística - Estoque, Armazenagem, DepósitoNível hierárquico: OperacionalLocal de trabalho: São Paulo, SPRealizar o recebimento, conferência, passagem, etiquetagem e expedição de mercadoria.
# https://www.infojobs.com.br/vaga-de-assistente-departamento-pessoal-em-parana__7207508.aspx
# Área e especialização profissional: Recursos Humanos - Departamento PessoalNível hierárquico: AssistenteLocal de trabalho: Curitiba, PRAuxílio no fechamento de folha de pagamento. Auxílio no processo demissional (cálculo de rescisões, homologações internas e externas). Cálculo de férias. Cadastro de funcionários no sistema. Controle de arquivos e planilhas.
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-vendedor-tecnico-construcao-civil-em-rio-grande-do-sul__7207498.aspx
# Área e especialização profissional: Comercial, Vendas - Venda TécnicaNível hierárquico: ConsultorNúmero de vagas: 2Local de trabalho: Gravataí, RSAtuar com prospecção de clientes, contatos por telefone e e- mail, visitas a clientes e potenciais clientes. Atuar com acompanhamento de projetos, criação de estratégias de vendas junto com o supervisor, monitoramento do mercado, confecção de orçamentos. Preparação de relatórios.
# url nao existe mais
# url nao existe mais
# url nao existe mais
# https://www.infojobs.com.br/vaga-de
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-auxiliar-administrativo-o-setor-informatica-em-sao-paulo__7207632.aspx
# Área e especialização profissional: Administração - Administração GeralNível hierárquico: AuxiliarLocal de trabalho: São Paulo, SPProfissional prestará assistência na área administrativa, auxiliando nas atividades rotineiras e na gestão financeira, atualização de cadastro de clientes e suporte na área fiscal, desenvolvendo os processos de controles e arquivamento de dados, elaboração e digitação de documentos, alimentação de planilhas de internas, gerência de informações, dar suporte para as demais áreas da empresa.Conferência de entrega (recebimento) de mercadorias e notas fiscais, contas a receber, emissão e controle de notas de débito, relacionamento com clientes com atividades de follow-up e cobranças, relacionamento com empresas prestadoras de serviços com controle de cadastros e envio de extratos para pagamento, contato com demais atividades financeiras, além de contas a pagar e receber.Elaborar propostas, realizar cotações, acompanhar os pedidos de vendas, prestar apoio no desenvolvimento de propostas comerciais e elabora relatórios sobre tendências de mercado, demanda e concorrentes, mapear o mercado, prospectar novos cliente e acompanhar os pedidos de vendas.Realização de inventário e publicação de anúncios de produtos/materiais em plataformas de vendas, como a OLX. Elaborar relatórios e planilhas de controle, atender os clientes via e-mail e telefone, Negociar prazos e valores.Capacidade de organização, boa comunicação escrita e verbal, dinâmica, agilidade e fluidez. Aplicações de Escritório: Microsoft Excel, Microsoft Outlook, Microsoft Word, Teams;
# url nao existe mais
# url nao existe mais
# url nao existe mais
# url nao existe mais
# url nao existe mais
# url nao existe mais
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-auxiliar-producao-caieiras-sp-em-sao-paulo__7207631.aspx
# Área e especialização profissional: Industrial, Produção, Fábrica - ProduçãoNível hierárquico: AuxiliarLocal de trabalho: Caieiras, SPFormação AcadêmicaEnsino Médio. Desejável conhecimento em informática, metrologia, experiência com operação de ponte rolante.Responsabilidade do CargoAuxiliar no carregamento e descarregamento de materiais (tubos, barras, chapas). Conferencia e separação de estoque. Auxílio aos operadores no abastecimento de máquinas, amarração de peças, lixamento e polimento.ExigênciasExperiência Anterior entre 1 e 3 anos com em produção, preferencialmente em metalúrgica/siderúrgica.
# https://www.infojobs.com.br/vaga-de-supervisor-estoque-lubrificantes-em-sao-paulo__7207633.aspx
# Área e especialização profissional: Logística - Estoque, Armazenagem, DepósitoNível hierárquico: SupervisorLocal de trabalho: São Paulo, SPA partir de diretrizes e políticas gerais definidas pela Gerência da área, este é o responsável pelo planejamento, organização, controle e execução das atividades desempenhadas pelos Estoquistas, Auxiliares de estoque e Conferentes, visando assegurar a integridade do estoque físico junto ao sistema ERP da empresa.Ensino Médio Completo (Curso Técnico e Superior será um diferencial)Conhecimento em informática básicoConhecimento básico em sistema ERP (Leituras de estoque / Ficha Kardex )Experiência mínima de 1 ano em Liderança de EquipesCarteira CNH  BCurso de EmpilhadeiraResidir nas proximidades da Zona Norte ou OesteNão fumanteInteressados enviar CV 97456-4445 arquivo em PDF ou WORD, candidatos fora do perfil será desclassificado do processo.
# https://www.infojobs.com.br/vaga-de-arquiteto-dados-sr-home-office-em-sao-paulo__7207634.aspx
# Área e especialização profissional: Informática, TI, Telecomunicações - TINível hierárquico: EspecialistaLocal de trabalho: São Paulo, SPExperiência com engenharia ou arquitetura de dados; - Ter sido parte de uma equipe de desenvolvimento mais ampla, pareando com pessoas desenvolvedoras e, idealmente, analistas de negócios, pessoas engenheiras de infraestrutura e designers; - Práticas ágeis como Scrum - Modelagem de dados relacional e multidimensional lógica e física; - BI, Analytics e Big Data; - Desenvolvimento, projetos e ambientes Big Data; - Universo Hadoop, Python, Spark, Pyspark; - Microsoft Azure; - PowerBI, DAX, Azure Data Lake, Stream Analytics, Governança de dados e arquitetura de dados
# url nao existe mais
# url nao existe mais
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-camareira-hotel-em-rio-grande-do-sul__7207620.aspx
# Área e especialização profissional: Hotelaria, Turismo - HotelariaNível hierárquico: AuxiliarLocal de trabalho: Canoas, RSOrganizar e higienizar os apartamentos e corredores do Hotel.Higienizar  banheiros, retirar lixos e trocar  toalhas/ lençóis.Necessário experiência em limpeza, organização e higienização.
# url nao existe mais
# url nao existe mais
# url nao existe mais
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-advogado-junior-em-sao-paulo__7207613.aspx
# Área e especialização profissional: Jurídica - Advocacia GeralNível hierárquico: OperacionalLocal de trabalho: São Paulo, SPEscritório de advocacia especializado em Direito de imigração, contrata advogado que atue em alguma dessas áreas:  Direito Cível, ou Administrativo.Residir proximo ao local de trabalho (Tatuapé, Carrão, Penha, Vila Matilde, Arthur Alvim, Itaquera) e regiões.
# https://www.infojobs.com.br/vaga-de-operador-caixa-temporaria-guaratingueta-em-sao-paulo__7207614.aspx
# Área e especialização profissional: Comercial, Vendas - Lojas / ShoppingNível hierárquico: OperacionalLocal de trabalho: Guaratinguetá, SPSerá responsável pelos recebíveis, autenticações e demais operações realizadas no caixa, deve prestar um ótimo atendimento ao cliente, demosntrando interesse para ajudá-lo em quaisquer dúvidas.
# https://www.infojobs.com.br/vaga-de-comprador-em-sao-paulo__7207612.aspx
# Área e especialização profissional: Compras - ComprasNível hierárquico: EspecialistaLocal de trabalho: Itaquaquecetuba, SP	Analisar a compra matérias-primas, realizar cotação e negociação com fornecedores, emitir pedidos e acompanhar o fluxo de entrega para cumprimento de todas as condições negociadas.	Projetos de Redução de Custos	Conhecimento na comodities de Aços Longos e Planos, contatos em distribuidores e Usinas	Compra estratégica	Homologação de novos fornecedores	Qualificação de fornecedores	Avaliação de performance do fornecedor
# https://www.infojobs.com.br/vaga-de-eletricista-montador-paineis-suzano-em-sao-paulo__7207610.aspx
# Área e especialização profissional: Construção, Manutenção - Eletricista / Manutenção ElétricaNível hierárquico: OperacionalLocal de trabalho: Suzano, SPExperiência na funçãoNecessário ter trabalhado na área de manutenção elétrica industrialTer NR10 (40 horas + reciclagem) e NR35Ter cursos técnicos de eletricista Industrial, comandos elétricos, montagem de painéis, etcMorar em SuzanoSegunda à sexta-feira, das 7h ás 16h48 2320,00 + periculosidade + VT + refeição no localEmpresa localizada em Suzano
# https://www.infojobs.com.br/vaga-de-gestor-comercial-ramo-alimenticio-em-parana__7193885.aspx
# Área e especialização profissional: Comercial, Vendas - Venda Interna Nível hierárquico: OperacionalNúmero de vagas: 5Local de trabalho: Belo Horizonte, MGOportunidade incrível para consultor de vendas!!!Para essa posição, esperamos que você...Seja apaixonado(a) por pessoas e negocios, e se preocupe em proporcionar a melhor experiência durante o atendimento.Foque nas melhores soluções para garantia de satisfação dos clientes.Tenha compromisso com as entregas sendo protagonista da sua carreira.Ter resiliência é importante para lidar com situações críticas.Ouça de maneira analítica e empática durante as tratativas.Se identificou? Candidata-se para nossa  no email  Responsável por realizar atendimento ao cliente por telefone .Responsável por executar atividades relacionadas à venda de produtos ou serviços onde seu foco é entender e satisfazer as necessidades do cliente. Responsável pelas vendas, pela negociação de preços dos produtos ou serviços vendidos, conforme tabela de preços autorizada, negociação de prazo, das condições de pagamento e dos descontos da venda, de acordo com alçadas de aprovação.
# https://www.infojobs.com.br/vaga-de-auxiliar-fiscal-i-em-rio-janeiro__7207208.aspx
# Área e especialização profissional: Contábil, Finanças, Economia - ContabilidadeNível hierárquico: AuxiliarNúmero de vagas: 2Local de trabalho: Rio de Janeiro, RJCompetências imprescindíveis: Cursando em Ciências Contábeis ou Ensino superior completo.Recebimento, importação e classificação de notas fiscais.Elaboração de SPED Fiscal e SPED Contribuições. Conhecimento da legislação do ICMS RJ, PIS/COFINS e ISS. Conhecimento de NFe, SPED Fiscal e Contribuições. Conhecimento intermediário no pacote Office. Capacidade crítica Visão sistêmica Criatividade Trabalho em equipe Visão cliente e de negócio
# https://www.infojobs.com.br/vaga-de-arte-finalista-em-sao-paulo__7207197.aspx
# Área e especialização profissional: Moda - ModaNível hierárquico: OperacionalLocal de trabalho: São Paulo, SPo candidato deve sabe mecher no foto shop limpar imagem salvar imagem desenvolver desenhos
# https://www.infojobs.com.br/vaga-de-supervisor-vendas-call-center-em-sao-paulo__7207609.aspx
# Área e especialização profissional: Comercial, Vendas - AtendimentoNível hierárquico: SupervisorLocal de trabalho: São Paulo, SPSupervisionar sua equipe e garantir que 80% de seu tempo seja dedicado a gestão dos Agentes de Atendimento. Apoiar, motivar, avaliar, desenvolver e treinar seus Agentes para que constantemente possam alcançar e exceder suas metas individuais e de equipe .Interagir com outros Departamentos (WFM, Qualidade, Folha de Pagamento, RH, etc).Garantir que todas as políticas e procedimentos da TP sejam aderentes, mas não limitando-se a Segurança da Informação, RH, Operações, etc. Qualquer infração, de qualquer uma dessas políticas e procedimentos, deve ser comunicada à Gestão TP apropriada imediatamente. Atuar em conjunto com algum "Ponto Focal" para identificar problemas e gerar planos de ação para os KPIs avaliados. Manter e entregar proativamente o nível de serviço solicitado, enquanto maximiza a produtividade da equipe, para garantir que as metas sejam atingidas. Realizar monitoramento regular de como sua equipe interage com o cliente Apple e fornecer feedback, treinamento e educação apropriados para garantir que os Agentes cumpram aos requisitos e níveis de atendimento exigidos. Fornecer apoio em tempo real aos Agentes com dificuldades em chamadas e lidar com chamadas de clientes mais atritados, solucionando o caso pronta e profissionalmente quando necessário.
# url nao existe mais

# %%
cada_link
# Out:
# 'https://www.infojobs.com.br/vaga-de-auxiliar-operacoes-logistica-reposicao-centro-em-sao-paulo__7227410.aspx'

# %%
def re_scraping():
    
    dados_infojobs = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    for link in df_list_url:
        cada_link = link

        try:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            time.sleep(2)    
            r = requests.get(cada_link,allow_redirects=False)
            
            if r.status_code == 200:
                print(link)
                soup = BeautifulSoup(re, "html.parser")
                try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                    conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
                except:
                    conteudo = 'None'  
                try:   
                    exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    exigencias = 'None' 
                try:
                    beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    beneficios = 'None'
                dados = {'conteudo':conteudo,
                    'exigencias':exigencias,
                    'beneficios':beneficios,
                    'url':link}
                dados_infojobs.append(dados)
                df = pd.DataFrame(dados_infojobs)
                df.to_csv('dados_infojobs.csv')
            else:
                print('url nao existe mais')
            
        except:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            time.sleep(2)    
            r = requests.get(cada_link,allow_redirects=False)
             
            if r.status_code == 200:
                print(link)
                soup = BeautifulSoup(re, "html.parser")
                try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                    conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
                except:
                    conteudo = 'None'  
                try:   
                    exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    exigencias = 'None' 
                try:
                    beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    beneficios = 'None'
                dados = {'conteudo':conteudo,
                    'exigencias':exigencias,
                    'beneficios':beneficios,
                    'url':link}
                dados_infojobs.append(dados)
                df = pd.DataFrame(dados_infojobs)
                df.to_csv('dados_infojobs.csv')
            else:
                print('url nao existe mais')
                
                
            
    return cada_link
                            
if __name__ == '__main__':
    re_scraping() #apenas link
    #url_chosen()
# Out:
# url nao existe mais
# url nao existe mais
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-atendimento-bh-em-minas-gerais__7206929.aspx
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-consultor-vendas-em-pernambuco__7206056.aspx
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-instrutor-solda-em-parana__7207541.aspx
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-auxiliar-manutencao-campinas-em-sao-paulo__7207543.aspx
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-comprador-construcao-civil-em-rio-grande-do-sul__7207535.aspx
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-advogado-em-rio-grande-do-sul__7207532.aspx
# url nao existe mais
# https://www.infojobs.com.br/vaga-de-fiscal-obras-construtora-em-rio-grande-do-sul__7207523.aspx

# %%
url = 'https://br.indeed.com/ver-emprego?cmp=AeC&t=Atendente+Telemarketing+Home+Office&jk=70fc938645bf479b&sjdu=ExohQoCyKniFwdrlpnK3D8LltcuziXe37SkCnGZ5CNMMFS1rcL1qC-7hCxCpIFVoGSOhVYnsuo2h37dFAQy10jQ2b9Il319ZICwwVIqdchs&adid=367867321&ad=-6NYlbfkN0A3IIgIh4aPQsGKwQVAjXwRlDN3xgooWtQNG1aTIQ823iO2WLLjQagOtZ399hkZ0n_Iu0lm5sLKEhGEB-75yu8Aa8pcMNffrQpaTm2i_blFO3368SBB94EY4yfToTwctWjNp26ysZ8STLPhU4WFw5LRsDB53TYhec4hQXSXX3wGeNmJOHF67GfmVl7RJMYjsLVc3KJbkUSH37bQZUwHjF-ckJhlxZdAQaVXpptHCo_8CKfd_KqgrqLmg_tLr-PXK4RKHjP7bufe6bbaZg1jjJ0BDwDBcAbeP845TPRxku0mvNoX0jGDjwHFP3Z_1gYpK7Djm08og8cIV9suIu9ybhlIEudN6yOJtlQmtpB-u1Ireg94BfLDVLIv&vjs=3'

# %%
dados_infojobs = []
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
url = cada_link
    
re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
time.sleep(2)    
r = requests.get(cada_link,allow_redirects=False)

if r.status_code == 200:
    print(link)
    soup = BeautifulSoup(re, "html.parser")
    try:
    #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
        conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
    except:
        conteudo = 'None'  
    try:   
        exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
    except:
        exigencias = 'None' 
    try:
        beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
    except:
        beneficios = 'None'
    dados = {'conteudo':conteudo,
        'exigencias':exigencias,
        'beneficios':beneficios,
        'url':link}
    dados_infojobs.append(dados)
    df = pd.DataFrame(dados_infojobs)
    df.to_csv('dados_infojobs.csv')
else:
    print('url nao existe mais')

# %%
url =  'https://br.indeed.com/cmp/Aec-Centro-De-Contatos'
dados_infojobs = []
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
cada_link = url
    
re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
time.sleep(2)    
r = requests.get(cada_link,allow_redirects=False)

soup = BeautifulSoup(re, "html.parser")

#
#
#

option = webdriver.ChromeOptions()
option.add_argument('headless')
chromedriver = 'C:/Users/Zng-LENOVO/Desktop/CNI-PNUD/produto 1/Indeed produto 1/Indeed Re_scraping/chromedriver'
#driver = webdriver.Chrome(chromedriver)
driver = webdriver.Chrome(chromedriver,options=option)
driver.get(url)

elements = driver.find_elements_by_xpath('//div[@class="css-5xsqqw-Box eu4oa1w0"]')   
for element in elements:
    print(element.text)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1fbf2ecf9fb55768f28232bc1d5ea467", element="fb52cb77-df25-440e-bfca-bb3a0d1b70e0")>]

# %%
for element in elements:
    print(element.text)
# Out:
# Fortalecer vocações, a nossa vocação.
# Para a AeC, toda empresa possui uma vocação.
# Bancos operam finanças. Telefônicas conectam pessoas. Hospitais cuidam
# da vida.
# A vocação da AeC é fortalecer vocações.
# E isso ela faz quando traz para si a responsabilidade por uma série de serviços
# fundamentais a vários negócios, mas que não fazem parte de seus objetivos
# principais.
# Outsourcing, como se diz.
# É o que a gente faz.
# E que contribui para que diversas empresas foquem em prestar serviços cada vez melhores para milhões de pessoas.
# Inclusive você.

# %%
soup = BeautifulSoup(re, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="pt">
# <head>
# <title>Carreiras e Empregos — AeC Centro de Contatos | Indeed.com</title>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <meta content="Descubra o que funciona bem na empresa AeC Centro de Contatos por meio das pessoas mais entendidas do assunto. Obtenha informações privilegiadas sobre vagas, salários, principais locais de trabalho e visão do CEO. Compare o salário de cargos populares e leia sobre o equilíbrio entre trabalho e vida pessoal. Descubra por que a empresa AeC Centro de Contatos é a melhor para você." name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="115882278440564" property="fb:app_id"/>
# <meta content="Carreiras e Empregos — AeC Centro de Contatos" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://d3hbwax96mbv6t.cloudfront.net/shared/static/images/indeed_fb.png" property="og:image"/>
# <meta content="/cmp/Aec-Centro-De-Contatos" property="og:url"/>
# <meta content="Descubra o que funciona bem na empresa AeC Centro de Contatos por meio das pessoas mais entendidas do assunto. Obtenha informações privilegiadas sobre vagas, salários, principais locais de trabalho e visão do CEO. Compare o salário de cargos populares e leia sobre o equilíbrio entre trabalho e vida pessoal. Descubra por que a empresa AeC Centro de Contatos é a melhor para você." property="og:description"/>
# <meta content="Indeed.com" property="og:site_name"/>
# <link href="/cmp/Aec-Centro-De-Contatos" rel="canonical"/>
# <link href="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/s/7523265/legacy-base.css" rel="stylesheet" type="text/css"/>
# <link href="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/a93107e3302c0d8e91ee/css/vendor.css" rel="stylesheet" type="text/css"/>
# <link href="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/982c705e04cab65d5f79/css/snapshot-client.css" rel="stylesheet" type="text/css"/>
# <link href="/images/favicon.ico" rel="icon"/>
# <script type="text/javascript">
#         window.__JSERROR__=[];window.onerror=function() { window.__JSERROR__.push(arguments)}
#     </script>
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5BCKBTQ');
#     </script>
# <style>
#         body { margin-top: 0; margin-left: 0; margin-right: 0; padding-top: 0; padding-right: 0; padding-left: 0; }
#     </style>
# </head>
# <body>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5BCKBTQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div>
# <script id="_indeed_gnav_config" type="application/json">{"isEmployer":false,"isMobile":false,"desktopPageLinks":[{"text":"Achar vagas","href":"https://br.indeed.com/","dataHref":"https://br.indeed.com/?from=gnav-acme--acme-webapp","isHighlighted":false,"dataGnavElementName":"FindJobs"},{"text":"Avaliações de Empresas","href":"https://br.indeed.com/companies","dataHref":"https://br.indeed.com/companies?from=gnav-acme--acme-webapp","isHighlighted":true,"dataGnavElementName":"CompanyReviews"},{"text":"Achar salários","href":"https://br.indeed.com/career/salaries","dataHref":"https://br.indeed.com/career/salaries?from=gnav-acme--acme-webapp","isHighlighted":false,"dataGnavElementName":"FindSalaries"}],"resumeLink":{"text":"Cadastre seu currículo (Grátis!)","href":"https://br.indeed.com/promo/resume","dataHref":"https://br.indeed.com/promo/resume?from=gnav-acme--acme-webapp","isHighlighted":false,"dataGnavElementName":"UploadYourResume"},"skipNavLinkModel":{"href":"#gnav-header-end","text":"Ir para o conteúdo principal","targetText":"Início do conteúdo principal","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"Empresas/Anunciar vagas","href":"https://br.indeed.com/hire?co=BR\u0026hl=pt","dataHref":"https://br.indeed.com/hire?co=BR\u0026hl=pt\u0026from=undefined\u0026ikw=gnav-header-hire\u0026isid=employerlink-BR","dataGnavElementName":"EmployersPostJob"},"country":"BR","logoHref":"https://br.indeed.com?from=gnav-acme--acme-webapp","logoName":"aurora","appName":"acme--acme-webapp","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802\u0026co=BR\u0026hl=pt\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802\u0026co=BR\u0026hl=pt","logRoute":"https://t.indeed.com/gnav/log?from=acme--acme-webapp-%2Fcmp%2FAec-Centro-De-Contatos\u0026parentLogId=1f8e87v2bu1ba800\u0026hostAppTk=1f8e87utjn550802","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIcon":false,"inboxTestBucket":-1,"selectedIcon":"","shouldLowerNavIconMinWidth":true,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://br.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802","notificationHref":"https://br.indeed.com/notifications?from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802\u0026hl=pt","isNotificationTestActive":false,"isShowNotificationIcon":false,"notificationTestBucket":-1,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","isOnlineStatusActive":false,"onlineStatusApiHref":"https://employers.indeed.com/api/v2/messaging/onlinestatus/jobseeker?indeedcsrftoken=\u0026indeedClientApplication=gnav\u0026isClosed=false","signalsLogRoute":"https://t.indeed.com/signals/v1/log?from=acme--acme-webapp-%2Fcmp%2FAec-Centro-De-Contatos\u0026parentLogId=1f8e87v2bu1ba800\u0026hostAppTk=1f8e87utjn550802","serviceRequestLogUID":"1f8e87v2bu1ba800","hostAppTk":"1f8e87utjn550802","canonicalPageId":"","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","clickLogType":"gnavClick","clickLth":"fa8b0aff9499e52dd7e9215032d9ad9f","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","dwellTimeLogType":"gnavDwellTime","dwellTimeLth":"e415e44ee819f056fc4675c1b0373740","isPageSpeedLoggingEnabled":true,"passportAccountText":"Acessar","passportAccountURL":"https://secure.indeed.com/account/login?hl=pt_BR\u0026co=BR\u0026continue=https%3A%2F%2Fbr.indeed.com%2Fcmp%2FAec-Centro-De-C ...
# <script>
#             performance.mark('gnavRenderBlockingCSSHeader:end');
#             performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#         </script><nav aria-label="Principal" class="gnav" id="gnav-main-container"><div class="main" data-gnav-region="Main" data-reactroot=""><div class="gnav-DesktopHeaderContainer"><div class="gnav-DesktopHeader is-small-header with-skip-nav"><button class="icl-Button icl-Button--primary icl-Button--lg gnav-SkipNavLink" data-gnav-element-name="SkipNav" type="button"><span class="gnav-SkipNavLink-text">Ir para o conteúdo principal</span></button><div class="gnav-DesktopHeader-logo"><a class="gnav-Logo" data-gnav-element-name="Logo" href="https://br.indeed.com?from=gnav-acme--acme-webapp" title=""><span class="gnav-sr-only">Página inicial do Indeed</span><div aria-hidden="true" class="gnav-Logo-icon"><svg aria-hidden="true" fill="none" focusable="false" height="20" viewbox="0 0 75 20" width="75" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="
.994 7.451 7.451 0 0 0-.42 2.518c0 1.925.572 3.432 1.692 4.552 1.06 1.063 2.517 1.618 4.382 1.677.112.01.212.01.326.01.886 0 1.661-.109 2.343-.336.682-.229 1.244-.507 1.691-.843.46-.348.785-.704 1.01-1.07.223-.367.337-.695.337-.964 0-.307-.103-.555-.296-.723-.202-.17-.469-.26-.784-.26zm-6.562-5.346c.499-.526 1.142-.784 1.927-.784h.011c.814 0 1.477.258 1.976.773.509.517.795 1.3.877 2.35h-5.707c.112-1.03.419-1.814.916-2.339zM6.547 17.969v-7.301c.212.02.417.029.631.029a5.514 5.514 0 0 0 2.792-.744v8.014c0 .685-.163 1.19-.48 1.528-.315.336-.733.504-1.242.504-.5 0-.897-.168-1.223-.515-.315-.336-.478-.842-.478-1.515zm29.6-14.51c-.265-.298-.631-.449-1.09-.449-.48 0-.846.159-1.102.487-.264.317-.387.793-.387 1.417v4.524c-.59-.636-1.2-1.092- ...
# <script>
#     window.IndeedSentry = window.IndeedSentry || {};
#     window.IndeedSentry.preInitErrors = [];
#     window.IndeedSentry.preInitErrorCatcher = function (error) {
#         window.IndeedSentry.preInitErrors.push(error);
#     };
#     window.addEventListener("error", window.IndeedSentry.preInitErrorCatcher);
#     </script>
# <script>window.addEventListener("DOMContentLoaded", function() {
#     var s = document.createElement("script");
#     s.src = "https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?1";
#     s.crossorigin = "anonymous";
#     document.body.appendChild(s);
# });</script><script crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/428a6892cae4ffa2e85c7fee2754ab4c/indeed/consent/0d4d9047-e9bb-46ba-b003-a0bd1f4a7d4f/OtAutoBlock.js"></script><script crossorigin="anonymous" data-domain-name="indeed.com" data-domain-script="0d4d9047-e9bb-46ba-b003-a0bd1f4a7d4f" data-ignore-geolocation="true" data-language="pt" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/428a6892cae4ffa2e85c7fee2754ab4c/indeed/scripttemplates/otSDKStub.js"></script><script type="application/javascript">
#         try {
#           setTimeout(function () {
#             try {
#               var SIMPLE_DOMAIN_MATCH_REGEX = /[a-z0-9][a-z0-9-]*\.[a-z]+$/i;
#               var DOMAIN_MATCH_REGEX = /[a-z0-9][a-z0-9-]+\.[a-z.]{2,6}$/i;
#               var extract_domain = function extract_domain(hostname) {
#                 var domain_regex = DOMAIN_MATCH_REGEX;
#                 var parts = hostname.split('.');
#                 var tld = parts[parts.length - 1];
#                 if (tld.length > 4 || tld === 'com' || tld === 'org') {
#                   domain_regex = SIMPLE_DOMAIN_MATCH_REGEX;
#                 }
#                 var matches = hostname.match(domain_regex);
#                 return matches ? matches[0] : '';
#               };
#               var cookies = document.cookie.split('; ');
#               for (var i = 0; i < cookies.length; i++) {
#                 if (cookies[i].indexOf('mp_') === 0 && cookies[i].length > 1000) {
#                   var cookieParts = cookies[i].split('=');
#                   document.cookie = cookieParts[0] + '=; path=/; domain=' + extract_domain(document.location.hostname) + '; Max-Age=-99999999;';
#                   document.cookie = cookieParts[0] + '=; path=/; Max-Age=-99999999;';
#                 }
#               }
#             } catch (e) {}
#           }, 100);
#         } catch (e) {}
#     </script></div><script>performance.mark('gnavRenderBlockingCSSHeader:start');</script><link href="https://d3fw5vlhllyvee.cloudfront.net/dist/da64c809927705db4cff/styles/google_one_tap.css" rel="stylesheet" type="text/css"/>
# <script>
#             performance.mark('gnavRenderBlockingCSSHeader:end');
#             performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#         </script><link as="script" href="https://d3fw5vlhllyvee.cloudfront.net/dist/1220f43f16316f4977f7/scripts/google_one_tap.js" rel="prefetch"/><script> window.addEventListener('DOMContentLoaded', function(e) { ["https://d3fw5vlhllyvee.cloudfront.net/dist/1220f43f16316f4977f7/scripts/google_one_tap.js"].forEach(function(p) { var s = document.createElement('script'); s.src = p; document.body.appendChild(s); }) }); </script>
# </div>
# <div class="turnstileInfo" data-tn-application="acme-webapp" data-tn-olth="ad40ce22551837d40d3253ae0aa5211b" data-tn-originlogid="1f8e87utjn550802" data-tn-originlogtype="acmePage" data-tn-page="snapshot" id="cmp-container">
# <div><div itemscope="" itemtype="http://schema.org/LocalBusiness"><div data-tn-section="header"><div class="cmp-Header-container" style="z-index:20;position:relative"><header class="cmp-CompactHeader" data-tn-section="header"><div class="cmp-CompactHeader-coverImageContainer cmp-CompactHeader-coverImageContainer--withMargin" style="background-color:rgba(255, 255, 255, 1)"><div aria-label="Imagem de Cabeçalho" class="cmp-CoverImage" data-testid="cmp-CoverImage" role="img" style="background-image:url('https://d2q79iu7y748jz.cloudfront.net/s/_headerimage/c62ee8cf811ff73eb5d97dcc153e38c4')"></div></div><div class="cmp-CompactHeaderStickyContainer"><div class="cmp-CompactHeaderStickyContainer-top"></div><div class="cmp-CompactHeaderStickyContainer-bottom"></div><div class="cmp-CompactHeaderStickyContainer-outerContainer" data-testid="cmp-CompactHeaderStickyContainer-outerContainer" style="background-color:rgba(255, 255, 255, 1)"><div class="cmp-CompactHeaderStickyContainer-innerContainer"><div class="cmp-CompactHeaderLayout" data-tn-component="cmp-CompactHeaderLayout"><div class="cmp-CompactHeaderLayout-container"><div class="cmp-CompactHeaderLayout-infoContainer"><div class="cmp-CompactHeaderLayout-companyInfo"><div class="cmp-CompactHeaderLayout-companyLogo"><div class="cmp-CompactHeaderCompanyLogo"><div class="cmp-CompactHeaderCompanyLogo-container"><img alt="Logotipo - AeC Centro de Contatos" class="cmp-CompactHeaderCompanyLogo-logo" itemprop="image" src="https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/3a1354c8eab738988cd8eb5611158224"/></div></div></div><div class="cmp-CompactHeaderLayout-nameRatings cmp-CompactHeaderLayout-nameRatings--extraMargin"><div class="cmp-CompactHeaderLayout-nameContainer"><span class="cmp-CompactHeaderCompanyName" itemprop="name">AeC Centro de Contatos</span></div><div class="cmp-CompactHeaderLayout-ratingContainer"><div class="cmp-CompactHeaderCompanyRatings"><span class="u-screenReaderOnly">3,9 de 5 estrelas.</span><span aria-hidden="true" class="cmp-CompactHeaderCompanyRatings-value">3,9</span><div aria-hidden="true" class="cmp-CompactHeaderCompanyRatings-star"><div class="cmp-RatingStars cmp-RatingStars--md"><div class="cmp-RatingStars-starsUnfilled"><div class="cmp-RatingStars-starsFilled" style="width:60.1856px"></div></div></div></div><div class="cmp-CompactHeaderCompanyRatings-reviewLink"><a class="cmp-RatingsCountLink" data-tn-element="reviews-countLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/reviews">3.578 avaliações</a></div></div></div></div></div><div class="cmp-CompactHeaderLayout-headerButton"><div class="cmp-FollowButton"><div class="cmp-FollowButton-buttonContainer"><div class="cmp-ColorButton"><style>
#                     .cmp-ColorButton-button#cmp-header-follow-button {
#                         background-color: rgba(8, 95, 247, 1);
#                         border-color: rgba(8, 95, 247, 1);
#                         color: rgba(255, 255, 255, 1);
#                     }
#                     .cmp-ColorButton-button#cmp-header-follow-button:hover,
#                     .cmp-ColorButton-button#cmp-header-follow-button:focus,
#                     .cmp-ColorButton-button#cmp-header-follow-button:active {
#                         background-color: rgba(8, 95, 247, 0.8);
#                         border-color: rgba(8, 95, 247, 0.8);
#                         color: rgba(255, 255, 255, 1);
#                     }
#                 </style><button class="cmp-ColorButton-button cmp-ColorButton-button--sm" data-tn-action-click="true" data-tn-element="cmp-FollowButton" id="cmp-header-follow-button">Seguir</button></div><div class="cmp-FollowButton-message">Receba atualizações semanais, vagas novas e avaliações</div></div></div></div></div><div class="cmp-CompactHeaderLayout-navContainer"><nav aria-label="secundário" class="cmp-NavMenu" id="cmp-skip-header-desktop"><div class="cmp-NavMenu-innerContainer"><ul class="cmp-NavMenu-list"><li class="cmp-CompactHeaderMenuItem cmp-CompactHeaderMenuItem--selected" data-tn-element="overview-tab"><a aria-label="Visão Geral, link, selecionado no momento" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos" rel="" style="border-bottom-color:rgba(8, 95, 247, 1)"><span aria-hidden="true">Visão Geral</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="about-tab"><a aria-label="Junte-se a nós" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/about" rel=""><span aria-hidden="true">Junte-se a nós</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="reviews-tab"><a aria-label="3.578 Avaliações" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/reviews" rel=""><div aria-hidden="true" class="cmp-CompactHeaderMenuItem-count" data-testid="dataCount">3.578</div><span aria-hidden="true">Avaliações</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="salaries-tab"><a aria-label="282 Salários" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/salaries" rel=""><div aria-hidden="true" class="cmp-CompactHeaderMenuItem-count" data-testid="dataCount">282</div><span aria-hidden="true">Salários</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="photos-tab"><a aria-label="49 Fotos" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/photos" rel=""><div aria-hidden="true" class="cmp-CompactHeaderMenuItem-count" data-testid="dataCount">49</div><span aria-hidden="true">Fotos</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="jobs-tab"><a aria-label="24 Empregos" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/jobs" rel=""><div aria-hidden="true" class="cmp-CompactHeaderMenuItem-count" data-testid="dataCount">24</div><span aria-hidden="true">Empregos</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="qna-tab"><a aria-label="109 Perguntas" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/faq" rel=""><div aria-hidden="true" class="cmp-CompactHeaderMenuItem-count" data-testid="dataCount">109</div><span aria-hidden="true">Perguntas</span></a></li><li class="cmp-CompactHeaderMenuItem" data-tn-element="interviews-tab"><a aria-label="Entrevistas" class="cmp-CompactHeaderMenuItem-link cmp-u-noUnderline" data-testid="compactHeaderMenuItemLink" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/interviews" rel="nofollow"><span aria-hidden="true">Entrevistas</span></a></li></ul></div></nav></div></div></div></div></div></div></header></div></div><main><div class="cmp-WonderPage"><h1 class="cmp-Wonder-PageHeading">Carreiras e Empregos — AeC Centro de Contatos</h1><div id="cmp-Wonder-Section-About"><div data-tn-section="AboutSection-section"><style data-emotion="css t3y14-Box">.css-t3y14-Box{box-sizing:border-box;margin:0;min-width:0;padding ...
#                                 5,
#                                 147px
#                             );grid-auto-rows:minmax(107px, 1fr);}}}</style><ul class="css-155g00k-Box eu4oa1w0"><style data-emotion="css 1m23au9-Box">.css-1m23au9-Box{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#ffffff;border:1px solid #f3f2f1;border-radius:0.5rem;padding:16px;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:relative;-webkit-flex:0 0 120px;-ms-flex:0 0 120px;flex:0 0 120px;margin:8px;box-sizing:border-box;word-wrap:break-word;}@supports (display: grid){.css-1m23au9-Box{margin:0;-webkit-flex:0 0 147px;-ms-flex:0 0 147px;flex:0 0 147px;}}</style><li class="css-1m23au9-Box eu4oa1w0" data-testid="companyInfo-industry"><style data-emotion="css 1et0vwh-Box">.css-1et0vwh-Box{box-sizing:border-box;margin:0;min-width:0;margin-bottom:16px;font-size:14px;font-weight:700;display:block;}</style><div class="css-1et0vwh-Box eu4oa1w0">Setor</div><style data-emotion="css 1cljifo-Box">.css-1cljifo-Box{box-sizing:border-box;margin:0;min-width:0;font-size:16px;}</style><div class="css-1cljifo-Box eu4oa1w0">Serviços de manutenção, reparação e construção</div></li></ul></div></div><style data-emotion="css 1yw9gi8-Box">.css-1yw9gi8-Box{box-sizing:border-box;margin:0;min-width:0;margin-top:24px;}@media screen and (min-width: 48rem){.css-1yw9gi8-Box{margin-top:48px;margin-left:80px;margin-right:80px;}}.css-1yw9gi8-Box p{color:#767676;}@media screen and (min-width: 48rem){.css-1yw9gi8-Box p{font-size:16px;}}</style><div class="css-1yw9gi8-Box eu4oa1w0"><style data-emotion="css 5xsqqw-Box">.css-5xsqqw-Box{box-sizing:border-box;margin:0;min-width:0;}.css-5xsqqw-Box p:last-of-type{margin-bottom:0;}</style><div class="css-5xsqqw-Box eu4oa1w0"></div></div><style data-emotion="css 14up2pp-Box">.css-14up2pp-Box{box-sizing:border-box;margin:0;min-width:0;margin-top:1rem;padding-left:0;padding-right:0;}@media screen and (min-width: 62rem){.css-14up2pp-Box{margin-top:2rem;}}</style><div class="css-14up2pp-Box eu4oa1w0"><style data-emotion="css fxw6sb-Link">.css-fxw6sb-Link{border-radius:0.25rem;color:#085ff7;font-family:"Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;-webkit-text-decoration:underline;text-decoration:underline;-webkit-transition:color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1);transition:color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:20px;font-weight:700;background:url(https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/assets/chevron-right-80831f.svg) 100% 40% no-repeat;padding-right:40px;}.css-fxw6sb-Link:hover{color:#0643ad;}.css-fxw6sb-Link:active{color:#042c72;}.css-fxw6sb-Link:focus{outline:none;box-shadow:0 0 0 1px #085ff7;}.css-fxw6sb-Link:focus:not([data-focus-visible-added]){outline:none;box-shadow:none;}</style><a class="css-fxw6sb-Link emf9s7v0" data-tn-element="explore-more" data-tn-link="true" href="/cmp/Aec-Centro-De-Contatos/about?from=acme-wonder">Saiba mais</a></div></section></div></div><div id="cmp-Wonder-Section-Jobs"><div data-tn-section="jobs-section-no-result"><style data-emotion="css 1fvhip1-Box">.css-1fvhip1-Box{box-sizing:border-box;margin:0;min-width:0;padding-top:1.5rem;padding-bottom:1.5rem;padding-left:0;padding-right:0;background-color:#FFFFFF;box-sizing:border-box;border-bottom:2px solid;border-bottom-color:#ececec;width:100%;margin-left:auto;margin-right:auto;}@media screen and (min-width: 48rem){.css-1fvhip1-Box{border-bottom:0;}}@media screen and (min-width: 62rem){.css-1fvhip1-Box{width:960px;}}</style><section class="cmp-WonderJobsSection css-1fvhip1-Box eu4oa1w0"><style data-emotion="css 15z8yv2-Box">.css-15z8yv2-Box{box-sizing: ...
# </div>
# <script>
#     window._initialData=JSON.parse('{"aboutSectionViewModel":{"aboutCompany":{"description":"Fortalecer vocações, a nossa vocação.\\r\\n \\r\\nPara a AeC, toda empresa possui uma vocação.\\r\\n\\r\\nBancos operam finanças. Telefônicas conectam pessoas. Hospitais cuidam\\r\\n da vida.\\r\\n\\r\\nA vocação da AeC é fortalecer vocações.\\r\\n\\r\\nE isso ela faz quando traz para si a responsabilidade por uma série de serviços\\r\\n fundamentais a vários negócios, mas que não fazem parte de seus objetivos\\r\\n principais.\\r\\n\\r\\nOutsourcing, como se diz.\\r\\n\\r\\n É o que a gente faz.\\r\\n\\r\\n E que contribui para que diversas empresas foquem em prestar serviços cada vez melhores para milhões de pessoas.\\r\\n\\r\\nInclusive você.\\r\\n","industry":"Serviços de manutenção, reparação e construção","name":"AeC Centro de Contatos"}},"baseUrl":"/cmp/Aec-Centro-De-Contatos","breadcrumbs":{"breadcrumbs":[{"name":"Empresas","noFollow":false,"url":"https://br.indeed.com/companies"},{"name":"AeC Centro de Contatos","noFollow":false}]},"companyName":"AeC Centro de Contatos","companyPageFooter":{"enabledToShowUserFeedbackForm":false,"encodedFccId":"b1f404fb53e3b248","stickyJobsTabLink":{"jobsLink":"/cmp/Aec-Centro-De-Contatos/jobs"}},"companyPageHeader":{"brandColor":"#00B5E2","companyHeader":{"name":"AeC Centro de Contatos","rating":3.9,"reviewCount":3578,"reviewCountFormatted":"3.578","reviewsUrl":"/cmp/Aec-Centro-De-Contatos/reviews","showClaimedProfile":false,"victoryHeader":false},"followButton":{"brandColor":"#00B5E2","compactType":-1,"companyName":"AeC Centro de Contatos","disclaimerRequired":false,"encodedFccId":"b1f404fb53e3b248","followSource":"acmeSnapshot","hashedCsrfToken":"7a7a8c0ff0453c1bf89150a99ab31daa","loggedIn":false},"headerImage":{"headerImageUrl":"https://d2q79iu7y748jz.cloudfront.net/s/_headerimage/c62ee8cf811ff73eb5d97dcc153e38c4","pageLanguage":"pt"},"headerVideoUrl":"","logoUrl":"https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/3a1354c8eab738988cd8eb5611158224","navMenuA11y":false,"showPremiumHeader":false,"simpleStickyHeader":false,"tabMenu":[{"name":"Visão Geral","nofollow":false,"selected":true,"turnstileElement":"overview-tab","url":"/cmp/Aec-Centro-De-Contatos"},{"name":"Junte-se a nós","nofollow":false,"selected":false,"turnstileElement":"about-tab","url":"/cmp/Aec-Centro-De-Contatos/about"},{"count":"3.578","name":"Avaliações","nofollow":false,"selected":false,"turnstileElement":"reviews-tab","url":"/cmp/Aec-Centro-De-Contatos/reviews"},{"count":"282","name":"Salários","nofollow":false,"selected":false,"turnstileElement":"salaries-tab","url":"/cmp/Aec-Centro-De-Contatos/salaries"},{"count":"49","name":"Fotos","nofollow":false,"selected":false,"turnstileElement":"photos-tab","url":"/cmp/Aec-Centro-De-Contatos/photos"},{"count":"24","name":"Empregos","nofollow":false,"selected":false,"turnstileElement":"jobs-tab","url":"/cmp/Aec-Centro-De-Contatos/jobs"},{"count":"109","name":"Perguntas","nofollow":false,"selected":false,"turnstileElement":"qna-tab","url":"/cmp/Aec-Centro-De-Contatos/faq"},{"name":"Entrevistas","nofollow":true,"selected":false,"turnstileElement":"interviews-tab","url":"/cmp/Aec-Centro-De-Contatos/interviews"}]},"encodedFccId":"b1f404fb53e3b248","interviewsSectionViewModel":{"formattedCount":"1.485","interviewQuestions":{"answers":[{"answerText":{"text":"Disponibilidade de horário, interesses profissionais."},"jobTitle":"Artífice","location":"Governador Valadares, MG","submissionDate":"24 de Junho de 2019"},{"answerText":{"text":"Gosta de trabalhar dialogando com pessoas"},"jobTitle":"Operador de Telemarketing Ativo","location":"Belo Horizonte, MG","submissionDate":"26 de Março de 2019"},{"answerText":{"text":"Como venderiam um produto fora do comercio."},"jobTitle":"Atendente De Telemarketing","location":"Belo Horizonte, MG","submissionDate":"28 de Janeiro de 2019"}],"companyName":"AeC Centro de Contatos","interviewQuestionURL":"/cmp/Aec-Centro-De-Contatos/faq/quais-perguntas-s%C3 ...
# </script>
# <script>
#     window._sentryData=JSON.parse('{"dsnAddress":"https://ecfd85d150d54e4fb18a450d40cff53a@sentry.indeed.com/49991","isEnabled":true,"releaseVersion":"2df215a48966c2cebc0788e743eb503625dc8c7a"}');
# </script>
# <script>
#     window['indeed.i18n.localeData']=JSON.parse('{"":{"Plural-Forms":" nplurals=2; plural=n != 1;","Content-Type":" text/plain; charset=UTF-8"},"Easy":[null,"Fácil"],"$5M to $25M (USD)":[null,"Entre 5 milhões e 25 milhões de dólares"],"Show more information":[null,"Mostrar mais informações"],"Shared on {0}":[null,"Compartilhada em {0}"],"$100M to $500M (USD)":[null,"Entre 100 milhões e 500 milhões de dólares"],"{0} Careers and Employment":[null,"Carreiras e Empregos — {0}"],"Interview insights":[null,"Informações sobre a entrevista"],"See {0} answer":[null,"Ver mais {0} resposta","Ver mais {0} respostas"],"{0} or lower":[null,"{0} ou menos"],"Return to Snapshot page":[null,"Voltar para página Visão geral"],"Follow":[null,"Seguir"]," in the industry. Rating is calculated based on {0} reviews and is evolving.":[null," no setor. A classificação foi calculada com base em {0} avaliações e é progressiva."],"Thank you for your feedback!":[null,"Agradecemos pelos seus comentários!"],"Reveal previous companies":[null,"Revelar empresas anteriores"],"Difficult":[null,"Difícil"],"Browse jobs by category":[null,"Procure vagas por categoria"],"Please enter a valid email.":[null,"Insira um e-mail válido."],"Explore more salaries":[null,"Pesquisar mais salários"],"$500M to $1B (USD)":[null,"Entre 500 milhões e 1 bilhão de dólares"],"Salaries":[null,"Salários"],"Write a review":[null,"Escrever uma avaliação"],"more...":[null,"mais..."],"5,001 to 10,000":[null,"Entre 5.001 e 10.000"],"What would you add or change?":[null,"O que você adicionaria ou alteraria?"],"Give Feedback":[null,"Enviar avaliações"],"$1M to $5M (USD)":[null,"Entre 1 milhão e 5 milhões de dólares"],"What would you say about your employer?":[null,"O que você diria sobre a empresa em que trabalha?"],"Get weekly updates, new jobs, and reviews":[null,"Receba atualizações semanais, vagas novas e avaliações"],"Explore {0}":[null,"Conheça a empresa {0}"],"Following is temporarily unavailable.":[null,"Este recurso está temporariamente indisponível."],"CEO":[null,"CEO"],"Job Security & Advancement":[null,"Estabilidade e promoção"],"secondary":[null,"secundário"],"Browse jobs nearby":[null,"Procure vagas nas imediações"],"Enter your email here:":[null,"Insira seu e-mail aqui:"],"Work & Life Balance":[null,"Equilíbrio entre trabalho e vida pessoal"],"Reviews":[null,"Avaliações"],"There is {0} job near {1}":[null,"Há {0} vaga perto de {1}","Há mais {0} vagas perto de {1}"],"$5B to $10B (USD)":[null,"Entre 5 bilhões e 10 bilhões de dólares"],"Low":[null,"Baixa"],"Click to hide answer":[null,"Clique para ocultar a resposta"],"Show less":[null,"Mostrar menos"],"Close":[null,"Fechar"],"Revenue":[null,"Receita"],"11 to 50":[null,"Entre 11 e 50"],"Company YouTube video modal":[null,"Modal de vídeo do YouTube da empresa"],"Questions and answers":[null,"Perguntas e respostas"],"{0}, link, currently selected":[null,"{0}, link, selecionado no momento"],"Working at {0}":[null,"Trabalhando na empresa {0}"],"[more than|key] 10,000":[null,"[mais de|key] 10.000"],"$25M to $100M (USD)":[null,"Entre 25 milhões e 100 milhões de dólares"],"Interview is difficult":[null,"A entrevista é difícil"],"Click to show answer of question: {0}":[null,"Clique para exibir a resposta da pergunta: {0}"],"Survey statements":[null,"Afirmações da pesquisa"],"See full report":[null,"Ver relatório completo"],"Jobs":[null,"Empregos"],"$1B to $5B (USD)":[null,"Entre 1 bilhão e 5 bilhões de dólares"],"Find another company":[null,"Encontre outra empresa"],"{0} review":[null,"{0} avaliação","{0} avaliações"],"Our survey participants responded to the following statements about this employer and gave a rating from 1 \\"strongly disagree\\" to 5 \\"strongly agree\\".":[null,"Os participantes da pesquisa responderam às afirmações abaixo sobre essa empresa e deram uma classificação de 1 (“discordo totalmente”) a 5 (“concordo totalmente”)."],"{0} logo":[null,"Logotipo - {0}"],"close":[null,"fechar"],"Work Happiness Score scale":[null,"N ...
# </script>
# <script src="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/8d09bd4035845c4eb164/js/manifest.js"></script>
# <script src="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/b21da75d11c72ede7e0e/js/vendor.js"></script>
# <script src="//t.indeed.com/s/6b964c2/turnstile-compiled.js"></script>
# <script src="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/6742192224caeecb8d1a/js/snapshot-client.js"></script>
# <script id="_indeed_gnav_footer_config" type="application/json">{"footerVariant":"DESKTOP_JOBSEEKER_FOOTER","desktopJobseekerFooterConfig":{"links":[{"description":"Guia de Carreira","href":"https://br.indeed.com/conselho-de-carreira","dataHref":"https://br.indeed.com/conselho-de-carreira?from=gnav-acme--acme-webapp\u0026ikw=jsfooter\u0026isid=jasx_us-en","dataGnavElementName":"CareerAdvice"},{"description":"Ver Empregos","href":"https://br.indeed.com/browsejobs","dataHref":"https://br.indeed.com/browsejobs?from=gnav-acme--acme-webapp","dataGnavElementName":"BrowseJobs"},{"description":"Salários","href":"https://br.indeed.com/career/salaries","dataHref":"https://br.indeed.com/career/salaries?from=gnav-acme--acme-webapp","dataGnavElementName":"Salaries"},{"description":"Indeed Eventos","href":"https://www.indeedevents.com/pt-br","dataHref":"https://www.indeedevents.com/pt-br?from=gnav-acme--acme-webapp","dataGnavElementName":"IndeedEvents"},{"description":"Ver todos...","href":"https://br.indeed.com/worldwide","dataHref":"https://br.indeed.com/worldwide?from=gnav-acme--acme-webapp","dataGnavElementName":"Countries"},{"description":"Sobre o Indeed","href":"https://br.indeed.com/about","dataHref":"https://br.indeed.com/about?from=gnav-acme--acme-webapp","dataGnavElementName":"About"},{"description":"Informações da empresa","href":"https://br.indeed.com/about/our-company","dataHref":"https://br.indeed.com/about/our-company?from=gnav-acme--acme-webapp","dataGnavElementName":"CompanyInfo"},{"description":"Central de Ajuda","href":"https://indeed.zendesk.com/hc/pt-br?redirect=false","dataHref":"https://indeed.zendesk.com/hc/pt-br?redirect=false\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"JobseekerHelpCenter"}],"impressumLinks":[{"description":"Acessibilidade no Indeed","href":"https://br.indeed.com/accessibility?hl=pt","dataHref":"https://br.indeed.com/accessibility?hl=pt\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"Accessibility"},{"description":"Centro de Privacidade","href":"https://hrtechprivacy.com/pt","dataHref":"https://hrtechprivacy.com/pt?from=gnav-acme--acme-webapp","dataGnavElementName":"PrivacyCenter"},{"description":"Cookies","href":"https://hrtechprivacy.com/pt/brands/indeed#Cookies","dataHref":"https://hrtechprivacy.com/pt/brands/indeed?from=gnav-acme--acme-webapp#Cookies","dataGnavElementName":"Cookies"},{"description":"Privacidade","href":"https://hrtechprivacy.com/pt/brands/indeed#privacypolicy","dataHref":"https://hrtechprivacy.com/pt/brands/indeed?from=gnav-acme--acme-webapp#privacypolicy","dataGnavElementName":"Privacy"}],"legalLink":{"description":"Termos","href":"https://br.indeed.com/legal?hl=pt","dataHref":"https://br.indeed.com/legal?hl=pt\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"Terms"},"year":2021},"logRoute":"https://t.indeed.com/gnav/log?from=acme--acme-webapp-%2Fcmp%2FAec-Centro-De-Contatos\u0026parentLogId=1f8e87v2bu1ba800\u0026hostAppTk=1f8e87utjn550802","serviceRequestLogUID":"1f8e87v2bu1ba800","hostAppTk":"1f8e87utjn550802","canonicalPageId":"","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","isPageSpeedLoggingEnabled":true,"isPreproduction":false,"publicPath":"https://d3fw5vlhllyvee.cloudfront.net/dist/"}</script><script>performance.mark('gnavRenderBlockingCSSFooter:start');</script><link href="https://d3fw5vlhllyvee.cloudfront.net/dist/ff2bb08e99a38b3887bd/styles/desktop_jobseeker_footer_external.css" rel="stylesheet" type="text/css"/>
# <script>
#             performance.mark('gnavRenderBlockingCSSFooter:end');
#             performance.measure('gnavRenderBlockingCSSFooter', 'gnavRenderBlockingCSSFooter:start', 'gnavRenderBlockingCSSFooter:end');
#         </script><div class="gnav" id="gnav-footer-container"><div class="main" data-gnav-region="MainFooter" data-reactroot=""><footer class="icl-GlobalFooter" role="contentinfo"><div class="icl-GlobalFooter-nav"><ul class="icl-GlobalFooter-items"><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="CareerAdvice" href="https://br.indeed.com/conselho-de-carreira">Guia de Carreira</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="BrowseJobs" href="https://br.indeed.com/browsejobs">Ver Empregos</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="Salaries" href="https://br.indeed.com/career/salaries">Salários</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="IndeedEvents" href="https://www.indeedevents.com/pt-br">Indeed Eventos</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="Countries" href="https://br.indeed.com/worldwide">Ver todos...</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="About" href="https://br.indeed.com/about">Sobre o Indeed</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="CompanyInfo" href="https://br.indeed.com/about/our-company">Informações da empresa</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="JobseekerHelpCenter" href="https://indeed.zendesk.com/hc/pt-br?redirect=false">Central de Ajuda</a></li></ul><ul class="icl-GlobalFooter-items"><li class="icl-GlobalFooter-item">© 2021 Indeed</li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="Accessibility" href="https://br.indeed.com/accessibility?hl=pt">Acessibilidade no Indeed</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="PrivacyCenter" href="https://hrtechprivacy.com/pt">Centro de Privacidade</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="Cookies" href="https://hrtechprivacy.com/pt/brands/indeed#Cookies">Cookies</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="Privacy" href="https://hrtechprivacy.com/pt/brands/indeed#privacypolicy">Privacidade</a></li><li class="icl-GlobalFooter-item"><a class="icl-GlobalFooter-link" data-gnav-element-name="Terms" data-href="https://br.indeed.com/legal?hl=pt&amp;from=gnav-acme--acme-webapp" href="https://br.indeed.com/legal?hl=pt">Termos</a></li></ul></div></footer></div></div><script>!function(){"use strict";var t,n,e,o,r,a,i,c,l,u,d,g={2620:function(t,n,e){e.d(n,{l9:function(){return o},eU:function(){return r},LE:function(){return a},Yy:function(){return i},zG:function(){return c},Lj:function(){return l},$:function(){return u}});var o="_INDEED_GNAV",r="#gnav-footer-container",a="#_indeed_gnav_config",i="#_indeed_gnav_footer_config",c="headerConfig",l="footerConfig",u=["button","a",'[role="button"]']}},v={};function f(t){var n=v[t];if(void 0!==n)return n.exports;var e=v[t]={exports:{}};return g[t](e,e.exports,f),e.exports}f.d=function(t,n){for(var e in n)f.o(n,e)&&!f.o(t,e)&&Object.defineProperty(t,e,{enumerable:!0,get:n[e]})},f.o=function(t,n){return Object.prototype.hasOwnProperty.call(t,n)},f.p="",o=f(2620),(r=null!==(e=null===(n=null===(t=window[o.l9])||void 0===t?void 0:t[o.zG])||void 0===n?void 0:n.publicPath)&&void 0!==e?e:"")&&(f.p=r),a=function(t){var n="";for(var e in t){var o=String(t[e]);n+=o?"&".concat(e,"=").concat(encodeURIComponent(o)):""}return n},i=f(2620),c=function(t){try{var n=document.head||document.body,e=document.createElement("script");e.src=t,n.appendChild(e),n.removeChild(e)}catch(t){}},l=function(t){if(!window[i.l9].loggedJSEnabled){window[i.l9].loggedJSEnabled=!0;var n=a(function(t){return{logType:t.jsEnabledLogType,lth:t.jsEna ...
# <script type="text/javascript">
#         PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
#         PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 1, 'acmeTest', 'true', 3];
#     </script>
# <script type="text/javascript">
#         PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
#         PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-8232301"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag(){dataLayer.push(arguments);}
#             gtag('js', new Date());
#             gtag('config', 'DC-8232301');
#         </script>
# <script type="text/javascript">
#             var ga_domains = [];
#                 ga_domains.push('indeed.co.in');
#                 ga_domains.push('indeed.lu');
#                 ga_domains.push('indeed.fr');
#                 ga_domains.push('indeed.com.br');
#                 ga_domains.push('indeed.de');
#                 ga_domains.push('indeed.co.uk');
#                 ga_domains.push('indeed.hk');
#                 ga_domains.push('indeed.fi');
#                 ga_domains.push('indeed.pt');
#                 ga_domains.push('indeed.jp');
#                 ga_domains.push('indeed.com');
#                 ga_domains.push('indeed.com.sg');
#                 ga_domains.push('indeed.nl');
#                 ga_domains.push('indeed.com.pk');
#                 ga_domains.push('indeed.cl');
#                 ga_domains.push('indeed.es');
#                 ga_domains.push('indeed.co.ve');
#                 ga_domains.push('indeed.com.mx');
#                 ga_domains.push('indeed.ae');
#                 ga_domains.push('indeed.ch');
#                 ga_domains.push('indeed.com.co');
#                 ga_domains.push('indeed.com.my');
#                 ga_domains.push('indeed.com.ph');
#                 ga_domains.push('indeed.co.za');
#                 ga_domains.push('indeed.ie');
#                 ga_domains.push('indeed.com.au');
#                 ga_domains.push('indeed.ca');
#                 ga_domains.push('indeed.com.pe');
#             (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function () {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }, i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#             var ga = ga || [];
#             ga('create', 'UA-90780-1', 'auto', {
#                 'allowLinker': true
#             });
#             ga('require', 'linkid');
#             ga('require', 'linker');
#             ga('linker:autoLink', ga_domains, false, true);
#             ga('require', 'displayfeatures');
#             ga('send', 'pageview');
#
#
#             (function () {
#                 if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
#                     for (var i in PENDING_ANALYTICS_VARS) {
#                         ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
#                     }
#                 }
#             })();
#         </script>
# <script>
#             window._comscore = window._comscore || [];
#             window._comscore.push({ c1: "2", c2: "6486505", c4:"br.indeed.com/cmp/Aec-Centro-De-Contatos", c15:"1f8e87utjn550801" });
#             (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#         </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=br.indeed.com%2Fcmp%2FAec-Centro-De-Contatos&amp;c15=1f8e87utjn550801&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
# </noscript>
# </body>
# </html>

# %%
soup.findAll('script')
# Out:
# [<script type="text/javascript">
#          window.__JSERROR__=[];window.onerror=function() { window.__JSERROR__.push(arguments)}
#      </script>,
#  <script>
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5BCKBTQ');
#      </script>,
#  <script id="_indeed_gnav_config" type="application/json">{"isEmployer":false,"isMobile":false,"desktopPageLinks":[{"text":"Achar vagas","href":"https://br.indeed.com/","dataHref":"https://br.indeed.com/?from=gnav-acme--acme-webapp","isHighlighted":false,"dataGnavElementName":"FindJobs"},{"text":"Avaliações de Empresas","href":"https://br.indeed.com/companies","dataHref":"https://br.indeed.com/companies?from=gnav-acme--acme-webapp","isHighlighted":true,"dataGnavElementName":"CompanyReviews"},{"text":"Achar salários","href":"https://br.indeed.com/career/salaries","dataHref":"https://br.indeed.com/career/salaries?from=gnav-acme--acme-webapp","isHighlighted":false,"dataGnavElementName":"FindSalaries"}],"resumeLink":{"text":"Cadastre seu currículo (Grátis!)","href":"https://br.indeed.com/promo/resume","dataHref":"https://br.indeed.com/promo/resume?from=gnav-acme--acme-webapp","isHighlighted":false,"dataGnavElementName":"UploadYourResume"},"skipNavLinkModel":{"href":"#gnav-header-end","text":"Ir para o conteúdo principal","targetText":"Início do conteúdo principal","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"Empresas/Anunciar vagas","href":"https://br.indeed.com/hire?co=BR\u0026hl=pt","dataHref":"https://br.indeed.com/hire?co=BR\u0026hl=pt\u0026from=undefined\u0026ikw=gnav-header-hire\u0026isid=employerlink-BR","dataGnavElementName":"EmployersPostJob"},"country":"BR","logoHref":"https://br.indeed.com?from=gnav-acme--acme-webapp","logoName":"aurora","appName":"acme--acme-webapp","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802\u0026co=BR\u0026hl=pt\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802\u0026co=BR\u0026hl=pt","logRoute":"https://t.indeed.com/gnav/log?from=acme--acme-webapp-%2Fcmp%2FAec-Centro-De-Contatos\u0026parentLogId=1f8e87v2bu1ba800\u0026hostAppTk=1f8e87utjn550802","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIcon":false,"inboxTestBucket":-1,"selectedIcon":"","shouldLowerNavIconMinWidth":true,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://br.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802","notificationHref":"https://br.indeed.com/notifications?from=gnav-util-acme--acme-webapp\u0026gnavTK=1f8e87v2bu1ba800\u0026tk=1f8e87utjn550802\u0026hl=pt","isNotificationTestActive":false,"isShowNotificationIcon":false,"notificationTestBucket":-1,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","isOnlineStatusActive":false,"onlineStatusApiHref":"https://employers.indeed.com/api/v2/messaging/onlinestatus/jobseeker?indeedcsrftoken=\u0026indeedClientApplication=gnav\u0026isClosed=false","signalsLogRoute":"https://t.indeed.com/signals/v1/log?from=acme--acme-webapp-%2Fcmp%2FAec-Centro-De-Contatos\u0026parentLogId=1f8e87v2bu1ba800\u0026hostAppTk=1f8e87utjn550802","serviceRequestLogUID":"1f8e87v2bu1ba800","hostAppTk":"1f8e87utjn550802","canonicalPageId":"","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","clickLogType":"gnavClick","clickLth":"fa8b0aff9499e52dd7e9215032d9ad9f","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","dwellTimeLogType":"gnavDwellTime","dwellTimeLth":"e415e44ee819f056fc4675c1b0373740","isPageSpeedLoggingEnabled":true,"passportAccountText":"Acessar","passportAccountURL":"https://secure.indeed.com/account/login?hl=pt_BR\u0026co=BR\u0026continue=https%3A%2F%2Fbr.indeed.com%2Fcmp%2FAec-Centro-De- ...
#  <script>performance.mark('gnavRenderBlockingCSSHeader:start');</script>,
#  <script>
#              performance.mark('gnavRenderBlockingCSSHeader:end');
#              performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#          </script>,
#  <script>!function(){var t={2128:function(){Element.prototype.matches||(Element.prototype.matches=Element.prototype.msMatchesSelector||Element.prototype.webkitMatchesSelector),Element.prototype.closest||(Element.prototype.closest=function(t){var e=this;do{if(e.matches(t))return e;e=e.parentElement||e.parentNode}while(null!==e&&1===e.nodeType);return null})},2620:function(t,e,n){"use strict";n.d(e,{he:function(){return o},l9:function(){return r},Yj:function(){return i},LE:function(){return a},zG:function(){return c},$:function(){return u}});var o="GLOBALNAV_CLICK_EVENT",r="_INDEED_GNAV",i="#gnav-main-container",a="#_indeed_gnav_config",c="headerConfig",u=["button","a",'[role="button"]']}},e={};function n(o){var r=e[o];if(void 0!==r)return r.exports;var i=e[o]={exports:{}};return t[o](i,i.exports,n),i.exports}n.d=function(t,e){for(var o in e)n.o(e,o)&&!n.o(t,o)&&Object.defineProperty(t,o,{enumerable:!0,get:e[o]})},n.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},n.p="",function(){"use strict";var t,e,o,r=n(2620),i=null!==(o=null===(e=null===(t=window[r.l9])||void 0===t?void 0:t[r.zG])||void 0===e?void 0:e.publicPath)&&void 0!==o?o:"";i&&(n.p=i)}(),function(){"use strict";var t=n(2620),e=function(){if("undefined"==typeof window)return null;if("function"==typeof window.CustomEvent)return window.CustomEvent;function t(t,e){e=e||{bubbles:!1,cancelable:!1,detail:{}};var n=document.createEvent("CustomEvent");return n.initCustomEvent(t,e.bubbles,e.cancelable,e.detail),n}return t.prototype=window.Event.prototype,t}(),o=function(n){var o=new e(t.he,{detail:{event:n}});document.dispatchEvent(o)},r=function(t){var e="";for(var n in t){var o=String(t[n]);e+=o?"&".concat(n,"=").concat(encodeURIComponent(o)):""}return e},i=function(t){try{var e=document.head||document.body,n=document.createElement("script");n.src=t,e.appendChild(n),e.removeChild(n)}catch(t){}},a=function(t,e){var n=r(function(t,e){return{logType:t.jsErrorLogType,lth:t.jsErrorLth,toString:e.toString(),message:e.message,stack:e.stack,name:e.name}}(t,e)),o=t.logRoute+n;return i(o)},c=function(e){if(!window[t.l9].loggedJSEnabled){window[t.l9].loggedJSEnabled=!0;var n=r(function(t){return{logType:t.jsEnabledLogType,lth:t.jsEnabledLth,jsEnabled:1}}(e)),o=e.logRoute+n;return i(o)}},u=function(){var e=arguments.length>0&&void 0!==arguments[0]?arguments[0]:t.LE,n=arguments.length>1&&void 0!==arguments[1]?arguments[1]:t.zG;try{return window[t.l9]=window[t.l9]||{},window[t.l9][n]=window[t.l9][n]||JSON.parse(document.querySelector(e).innerHTML),window[t.l9][n]}catch(t){return{}}},l=function(e){for(var n,o=window[t.l9].headerConfig&&window[t.l9].headerConfig.isPreproduction,a=0;a<t.$.length;a++){var c=t.$[a];if(e.target.closest(c)){n=c;break}}if(n){var l=e.target.closest("[data-gnav-element-name]"),d=l?l.getAttribute("data-gnav-element-name"):null;if(!d&&o)throw Error("Clickable element '".concat(n,"' must have 'data-gnav-element-name' attribute."));var f=e.target.closest("[data-gnav-region]"),s=f?f.getAttribute("data-gnav-region"):null;if(!s&&o)throw Error("Clickable element '".concat(n,"' must be within an element with 'data-gnav-region' attribute."));var v=e.target.closest("[data-gnav-action]");!function(t,e,n){var o=u();i(o.logRoute+r(function(t,e,n,o){return{logType:t.clickLogType,lth:t.clickLth,elementName:e,region:n,action:o}}(o,t,e,n)))}(d,s,v&&v.getAttribute("data-gnav-action")?v.getAttribute("data-gnav-action"):"nav")}};n(2128);!function(){var e,n;try{e=u(),window[t.l9]=window[t.l9]||{},(n=document.querySelector(t.Yj)).addEventListener("click",o,!1),n.addEventListener("click",l,!0),window[t.l9].GLOBALNAV_CLICK_EVENT=t.he,window[t.l9].initialized=!0;var r=function(t){return a(e,t&&t.error)},i=function(t,e){e&&(t.crossorigin="anonymous"),t.onerror=r},d=function(t,e){var n=document.createElement("script");return n.src=t,i(n,e),n},f=function(t,e){t.forEach((function(t){var n=d(t,e);document.body.appendChild(n)}))};window[t.l9].loadScriptsDeferred=function(t,e){t.f ...
#  <script> window.addEventListener('DOMContentLoaded', function(e) { ["https://d3fw5vlhllyvee.cloudfront.net/dist/3c84c7ae4da9894507b6/scripts/desktop_jobseeker_header_external.js"].forEach(function(p) { var s = document.createElement('script'); s.src = p; document.body.appendChild(s); }) }); </script>,
#  <script>
#      window.IndeedSentry = window.IndeedSentry || {};
#      window.IndeedSentry.preInitErrors = [];
#      window.IndeedSentry.preInitErrorCatcher = function (error) {
#          window.IndeedSentry.preInitErrors.push(error);
#      };
#      window.addEventListener("error", window.IndeedSentry.preInitErrorCatcher);
#      </script>,
#  <script>window.addEventListener("DOMContentLoaded", function() {
#      var s = document.createElement("script");
#      s.src = "https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?1";
#      s.crossorigin = "anonymous";
#      document.body.appendChild(s);
#  });</script>,
#  <script crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/428a6892cae4ffa2e85c7fee2754ab4c/indeed/consent/0d4d9047-e9bb-46ba-b003-a0bd1f4a7d4f/OtAutoBlock.js"></script>,
#  <script crossorigin="anonymous" data-domain-name="indeed.com" data-domain-script="0d4d9047-e9bb-46ba-b003-a0bd1f4a7d4f" data-ignore-geolocation="true" data-language="pt" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/428a6892cae4ffa2e85c7fee2754ab4c/indeed/scripttemplates/otSDKStub.js"></script>,
#  <script type="application/javascript">
#          try {
#            setTimeout(function () {
#              try {
#                var SIMPLE_DOMAIN_MATCH_REGEX = /[a-z0-9][a-z0-9-]*\.[a-z]+$/i;
#                var DOMAIN_MATCH_REGEX = /[a-z0-9][a-z0-9-]+\.[a-z.]{2,6}$/i;
#                var extract_domain = function extract_domain(hostname) {
#                  var domain_regex = DOMAIN_MATCH_REGEX;
#                  var parts = hostname.split('.');
#                  var tld = parts[parts.length - 1];
#                  if (tld.length > 4 || tld === 'com' || tld === 'org') {
#                    domain_regex = SIMPLE_DOMAIN_MATCH_REGEX;
#                  }
#                  var matches = hostname.match(domain_regex);
#                  return matches ? matches[0] : '';
#                };
#                var cookies = document.cookie.split('; ');
#                for (var i = 0; i < cookies.length; i++) {
#                  if (cookies[i].indexOf('mp_') === 0 && cookies[i].length > 1000) {
#                    var cookieParts = cookies[i].split('=');
#                    document.cookie = cookieParts[0] + '=; path=/; domain=' + extract_domain(document.location.hostname) + '; Max-Age=-99999999;';
#                    document.cookie = cookieParts[0] + '=; path=/; Max-Age=-99999999;';
#                  }
#                }
#              } catch (e) {}
#            }, 100);
#          } catch (e) {}
#      </script>,
#  <script>performance.mark('gnavRenderBlockingCSSHeader:start');</script>,
#  <script>
#              performance.mark('gnavRenderBlockingCSSHeader:end');
#              performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#          </script>,
#  <script> window.addEventListener('DOMContentLoaded', function(e) { ["https://d3fw5vlhllyvee.cloudfront.net/dist/1220f43f16316f4977f7/scripts/google_one_tap.js"].forEach(function(p) { var s = document.createElement('script'); s.src = p; document.body.appendChild(s); }) }); </script>,
#  <script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Empresas","item":"https://br.indeed.com/companies"},{"@type":"ListItem","position":2,"name":"AeC Centro de Contatos"}]}</script>,
#  <script>
#      window._initialData=JSON.parse('{"aboutSectionViewModel":{"aboutCompany":{"description":"Fortalecer vocações, a nossa vocação.\\r\\n \\r\\nPara a AeC, toda empresa possui uma vocação.\\r\\n\\r\\nBancos operam finanças. Telefônicas conectam pessoas. Hospitais cuidam\\r\\n da vida.\\r\\n\\r\\nA vocação da AeC é fortalecer vocações.\\r\\n\\r\\nE isso ela faz quando traz para si a responsabilidade por uma série de serviços\\r\\n fundamentais a vários negócios, mas que não fazem parte de seus objetivos\\r\\n principais.\\r\\n\\r\\nOutsourcing, como se diz.\\r\\n\\r\\n É o que a gente faz.\\r\\n\\r\\n E que contribui para que diversas empresas foquem em prestar serviços cada vez melhores para milhões de pessoas.\\r\\n\\r\\nInclusive você.\\r\\n","industry":"Serviços de manutenção, reparação e construção","name":"AeC Centro de Contatos"}},"baseUrl":"/cmp/Aec-Centro-De-Contatos","breadcrumbs":{"breadcrumbs":[{"name":"Empresas","noFollow":false,"url":"https://br.indeed.com/companies"},{"name":"AeC Centro de Contatos","noFollow":false}]},"companyName":"AeC Centro de Contatos","companyPageFooter":{"enabledToShowUserFeedbackForm":false,"encodedFccId":"b1f404fb53e3b248","stickyJobsTabLink":{"jobsLink":"/cmp/Aec-Centro-De-Contatos/jobs"}},"companyPageHeader":{"brandColor":"#00B5E2","companyHeader":{"name":"AeC Centro de Contatos","rating":3.9,"reviewCount":3578,"reviewCountFormatted":"3.578","reviewsUrl":"/cmp/Aec-Centro-De-Contatos/reviews","showClaimedProfile":false,"victoryHeader":false},"followButton":{"brandColor":"#00B5E2","compactType":-1,"companyName":"AeC Centro de Contatos","disclaimerRequired":false,"encodedFccId":"b1f404fb53e3b248","followSource":"acmeSnapshot","hashedCsrfToken":"7a7a8c0ff0453c1bf89150a99ab31daa","loggedIn":false},"headerImage":{"headerImageUrl":"https://d2q79iu7y748jz.cloudfront.net/s/_headerimage/c62ee8cf811ff73eb5d97dcc153e38c4","pageLanguage":"pt"},"headerVideoUrl":"","logoUrl":"https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/3a1354c8eab738988cd8eb5611158224","navMenuA11y":false,"showPremiumHeader":false,"simpleStickyHeader":false,"tabMenu":[{"name":"Visão Geral","nofollow":false,"selected":true,"turnstileElement":"overview-tab","url":"/cmp/Aec-Centro-De-Contatos"},{"name":"Junte-se a nós","nofollow":false,"selected":false,"turnstileElement":"about-tab","url":"/cmp/Aec-Centro-De-Contatos/about"},{"count":"3.578","name":"Avaliações","nofollow":false,"selected":false,"turnstileElement":"reviews-tab","url":"/cmp/Aec-Centro-De-Contatos/reviews"},{"count":"282","name":"Salários","nofollow":false,"selected":false,"turnstileElement":"salaries-tab","url":"/cmp/Aec-Centro-De-Contatos/salaries"},{"count":"49","name":"Fotos","nofollow":false,"selected":false,"turnstileElement":"photos-tab","url":"/cmp/Aec-Centro-De-Contatos/photos"},{"count":"24","name":"Empregos","nofollow":false,"selected":false,"turnstileElement":"jobs-tab","url":"/cmp/Aec-Centro-De-Contatos/jobs"},{"count":"109","name":"Perguntas","nofollow":false,"selected":false,"turnstileElement":"qna-tab","url":"/cmp/Aec-Centro-De-Contatos/faq"},{"name":"Entrevistas","nofollow":true,"selected":false,"turnstileElement":"interviews-tab","url":"/cmp/Aec-Centro-De-Contatos/interviews"}]},"encodedFccId":"b1f404fb53e3b248","interviewsSectionViewModel":{"formattedCount":"1.485","interviewQuestions":{"answers":[{"answerText":{"text":"Disponibilidade de horário, interesses profissionais."},"jobTitle":"Artífice","location":"Governador Valadares, MG","submissionDate":"24 de Junho de 2019"},{"answerText":{"text":"Gosta de trabalhar dialogando com pessoas"},"jobTitle":"Operador de Telemarketing Ativo","location":"Belo Horizonte, MG","submissionDate":"26 de Março de 2019"},{"answerText":{"text":"Como venderiam um produto fora do comercio."},"jobTitle":"Atendente De Telemarketing","location":"Belo Horizonte, MG","submissionDate":"28 de Janeiro de 2019"}],"companyName":"AeC Centro de Contatos","interviewQuestionURL":"/cmp/Aec-Centro-De-Contatos/faq/quais-perguntas-s%C ...
#  </script>,
#  <script>
#      window._sentryData=JSON.parse('{"dsnAddress":"https://ecfd85d150d54e4fb18a450d40cff53a@sentry.indeed.com/49991","isEnabled":true,"releaseVersion":"2df215a48966c2cebc0788e743eb503625dc8c7a"}');
#  </script>,
#  <script>
#      window['indeed.i18n.localeData']=JSON.parse('{"":{"Plural-Forms":" nplurals=2; plural=n != 1;","Content-Type":" text/plain; charset=UTF-8"},"Easy":[null,"Fácil"],"$5M to $25M (USD)":[null,"Entre 5 milhões e 25 milhões de dólares"],"Show more information":[null,"Mostrar mais informações"],"Shared on {0}":[null,"Compartilhada em {0}"],"$100M to $500M (USD)":[null,"Entre 100 milhões e 500 milhões de dólares"],"{0} Careers and Employment":[null,"Carreiras e Empregos — {0}"],"Interview insights":[null,"Informações sobre a entrevista"],"See {0} answer":[null,"Ver mais {0} resposta","Ver mais {0} respostas"],"{0} or lower":[null,"{0} ou menos"],"Return to Snapshot page":[null,"Voltar para página Visão geral"],"Follow":[null,"Seguir"]," in the industry. Rating is calculated based on {0} reviews and is evolving.":[null," no setor. A classificação foi calculada com base em {0} avaliações e é progressiva."],"Thank you for your feedback!":[null,"Agradecemos pelos seus comentários!"],"Reveal previous companies":[null,"Revelar empresas anteriores"],"Difficult":[null,"Difícil"],"Browse jobs by category":[null,"Procure vagas por categoria"],"Please enter a valid email.":[null,"Insira um e-mail válido."],"Explore more salaries":[null,"Pesquisar mais salários"],"$500M to $1B (USD)":[null,"Entre 500 milhões e 1 bilhão de dólares"],"Salaries":[null,"Salários"],"Write a review":[null,"Escrever uma avaliação"],"more...":[null,"mais..."],"5,001 to 10,000":[null,"Entre 5.001 e 10.000"],"What would you add or change?":[null,"O que você adicionaria ou alteraria?"],"Give Feedback":[null,"Enviar avaliações"],"$1M to $5M (USD)":[null,"Entre 1 milhão e 5 milhões de dólares"],"What would you say about your employer?":[null,"O que você diria sobre a empresa em que trabalha?"],"Get weekly updates, new jobs, and reviews":[null,"Receba atualizações semanais, vagas novas e avaliações"],"Explore {0}":[null,"Conheça a empresa {0}"],"Following is temporarily unavailable.":[null,"Este recurso está temporariamente indisponível."],"CEO":[null,"CEO"],"Job Security & Advancement":[null,"Estabilidade e promoção"],"secondary":[null,"secundário"],"Browse jobs nearby":[null,"Procure vagas nas imediações"],"Enter your email here:":[null,"Insira seu e-mail aqui:"],"Work & Life Balance":[null,"Equilíbrio entre trabalho e vida pessoal"],"Reviews":[null,"Avaliações"],"There is {0} job near {1}":[null,"Há {0} vaga perto de {1}","Há mais {0} vagas perto de {1}"],"$5B to $10B (USD)":[null,"Entre 5 bilhões e 10 bilhões de dólares"],"Low":[null,"Baixa"],"Click to hide answer":[null,"Clique para ocultar a resposta"],"Show less":[null,"Mostrar menos"],"Close":[null,"Fechar"],"Revenue":[null,"Receita"],"11 to 50":[null,"Entre 11 e 50"],"Company YouTube video modal":[null,"Modal de vídeo do YouTube da empresa"],"Questions and answers":[null,"Perguntas e respostas"],"{0}, link, currently selected":[null,"{0}, link, selecionado no momento"],"Working at {0}":[null,"Trabalhando na empresa {0}"],"[more than|key] 10,000":[null,"[mais de|key] 10.000"],"$25M to $100M (USD)":[null,"Entre 25 milhões e 100 milhões de dólares"],"Interview is difficult":[null,"A entrevista é difícil"],"Click to show answer of question: {0}":[null,"Clique para exibir a resposta da pergunta: {0}"],"Survey statements":[null,"Afirmações da pesquisa"],"See full report":[null,"Ver relatório completo"],"Jobs":[null,"Empregos"],"$1B to $5B (USD)":[null,"Entre 1 bilhão e 5 bilhões de dólares"],"Find another company":[null,"Encontre outra empresa"],"{0} review":[null,"{0} avaliação","{0} avaliações"],"Our survey participants responded to the following statements about this employer and gave a rating from 1 \\"strongly disagree\\" to 5 \\"strongly agree\\".":[null,"Os participantes da pesquisa responderam às afirmações abaixo sobre essa empresa e deram uma classificação de 1 (“discordo totalmente”) a 5 (“concordo totalmente”)."],"{0} logo":[null,"Logotipo - {0}"],"close":[null,"fechar"],"Work Happiness Score scale":[null," ...
#  </script>,
#  <script src="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/8d09bd4035845c4eb164/js/manifest.js"></script>,
#  <script src="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/b21da75d11c72ede7e0e/js/vendor.js"></script>,
#  <script src="//t.indeed.com/s/6b964c2/turnstile-compiled.js"></script>,
#  <script src="https://d3hbwax96mbv6t.cloudfront.net/cmp/_s/w/6742192224caeecb8d1a/js/snapshot-client.js"></script>,
#  <script id="_indeed_gnav_footer_config" type="application/json">{"footerVariant":"DESKTOP_JOBSEEKER_FOOTER","desktopJobseekerFooterConfig":{"links":[{"description":"Guia de Carreira","href":"https://br.indeed.com/conselho-de-carreira","dataHref":"https://br.indeed.com/conselho-de-carreira?from=gnav-acme--acme-webapp\u0026ikw=jsfooter\u0026isid=jasx_us-en","dataGnavElementName":"CareerAdvice"},{"description":"Ver Empregos","href":"https://br.indeed.com/browsejobs","dataHref":"https://br.indeed.com/browsejobs?from=gnav-acme--acme-webapp","dataGnavElementName":"BrowseJobs"},{"description":"Salários","href":"https://br.indeed.com/career/salaries","dataHref":"https://br.indeed.com/career/salaries?from=gnav-acme--acme-webapp","dataGnavElementName":"Salaries"},{"description":"Indeed Eventos","href":"https://www.indeedevents.com/pt-br","dataHref":"https://www.indeedevents.com/pt-br?from=gnav-acme--acme-webapp","dataGnavElementName":"IndeedEvents"},{"description":"Ver todos...","href":"https://br.indeed.com/worldwide","dataHref":"https://br.indeed.com/worldwide?from=gnav-acme--acme-webapp","dataGnavElementName":"Countries"},{"description":"Sobre o Indeed","href":"https://br.indeed.com/about","dataHref":"https://br.indeed.com/about?from=gnav-acme--acme-webapp","dataGnavElementName":"About"},{"description":"Informações da empresa","href":"https://br.indeed.com/about/our-company","dataHref":"https://br.indeed.com/about/our-company?from=gnav-acme--acme-webapp","dataGnavElementName":"CompanyInfo"},{"description":"Central de Ajuda","href":"https://indeed.zendesk.com/hc/pt-br?redirect=false","dataHref":"https://indeed.zendesk.com/hc/pt-br?redirect=false\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"JobseekerHelpCenter"}],"impressumLinks":[{"description":"Acessibilidade no Indeed","href":"https://br.indeed.com/accessibility?hl=pt","dataHref":"https://br.indeed.com/accessibility?hl=pt\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"Accessibility"},{"description":"Centro de Privacidade","href":"https://hrtechprivacy.com/pt","dataHref":"https://hrtechprivacy.com/pt?from=gnav-acme--acme-webapp","dataGnavElementName":"PrivacyCenter"},{"description":"Cookies","href":"https://hrtechprivacy.com/pt/brands/indeed#Cookies","dataHref":"https://hrtechprivacy.com/pt/brands/indeed?from=gnav-acme--acme-webapp#Cookies","dataGnavElementName":"Cookies"},{"description":"Privacidade","href":"https://hrtechprivacy.com/pt/brands/indeed#privacypolicy","dataHref":"https://hrtechprivacy.com/pt/brands/indeed?from=gnav-acme--acme-webapp#privacypolicy","dataGnavElementName":"Privacy"}],"legalLink":{"description":"Termos","href":"https://br.indeed.com/legal?hl=pt","dataHref":"https://br.indeed.com/legal?hl=pt\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"Terms"},"year":2021},"logRoute":"https://t.indeed.com/gnav/log?from=acme--acme-webapp-%2Fcmp%2FAec-Centro-De-Contatos\u0026parentLogId=1f8e87v2bu1ba800\u0026hostAppTk=1f8e87utjn550802","serviceRequestLogUID":"1f8e87v2bu1ba800","hostAppTk":"1f8e87utjn550802","canonicalPageId":"","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","isPageSpeedLoggingEnabled":true,"isPreproduction":false,"publicPath":"https://d3fw5vlhllyvee.cloudfront.net/dist/"}</script>,
#  <script>performance.mark('gnavRenderBlockingCSSFooter:start');</script>,
#  <script>
#              performance.mark('gnavRenderBlockingCSSFooter:end');
#              performance.measure('gnavRenderBlockingCSSFooter', 'gnavRenderBlockingCSSFooter:start', 'gnavRenderBlockingCSSFooter:end');
#          </script>,
#  <script>!function(){"use strict";var t,n,e,o,r,a,i,c,l,u,d,g={2620:function(t,n,e){e.d(n,{l9:function(){return o},eU:function(){return r},LE:function(){return a},Yy:function(){return i},zG:function(){return c},Lj:function(){return l},$:function(){return u}});var o="_INDEED_GNAV",r="#gnav-footer-container",a="#_indeed_gnav_config",i="#_indeed_gnav_footer_config",c="headerConfig",l="footerConfig",u=["button","a",'[role="button"]']}},v={};function f(t){var n=v[t];if(void 0!==n)return n.exports;var e=v[t]={exports:{}};return g[t](e,e.exports,f),e.exports}f.d=function(t,n){for(var e in n)f.o(n,e)&&!f.o(t,e)&&Object.defineProperty(t,e,{enumerable:!0,get:n[e]})},f.o=function(t,n){return Object.prototype.hasOwnProperty.call(t,n)},f.p="",o=f(2620),(r=null!==(e=null===(n=null===(t=window[o.l9])||void 0===t?void 0:t[o.zG])||void 0===n?void 0:n.publicPath)&&void 0!==e?e:"")&&(f.p=r),a=function(t){var n="";for(var e in t){var o=String(t[e]);n+=o?"&".concat(e,"=").concat(encodeURIComponent(o)):""}return n},i=f(2620),c=function(t){try{var n=document.head||document.body,e=document.createElement("script");e.src=t,n.appendChild(e),n.removeChild(e)}catch(t){}},l=function(t){if(!window[i.l9].loggedJSEnabled){window[i.l9].loggedJSEnabled=!0;var n=a(function(t){return{logType:t.jsEnabledLogType,lth:t.jsEnabledLth,jsEnabled:1}}(t)),e=t.logRoute+n;return c(e)}},u=function(){var t=arguments.length>0&&void 0!==arguments[0]?arguments[0]:i.LE,n=arguments.length>1&&void 0!==arguments[1]?arguments[1]:i.zG;try{return window[i.l9]=window[i.l9]||{},window[i.l9][n]=window[i.l9][n]||JSON.parse(document.querySelector(t).innerHTML),window[i.l9][n]}catch(t){return{}}},d=function(t){for(var n,e=window[i.l9].headerConfig&&window[i.l9].headerConfig.isPreproduction,o=0;o<i.$.length;o++){var r=i.$[o];if(t.target.closest(r)){n=r;break}}if(n){var l=t.target.closest("[data-gnav-element-name]"),d=l?l.getAttribute("data-gnav-element-name"):null;if(!d&&e)throw Error("Clickable element '".concat(n,"' must have 'data-gnav-element-name' attribute."));var g=t.target.closest("[data-gnav-region]"),v=g?g.getAttribute("data-gnav-region"):null;if(!v&&e)throw Error("Clickable element '".concat(n,"' must be within an element with 'data-gnav-region' attribute."));var f=t.target.closest("[data-gnav-action]");!function(t,n,e){var o=u();c(o.logRoute+a(function(t,n,e,o){return{logType:t.clickLogType,lth:t.clickLth,elementName:n,region:e,action:o}}(o,t,n,e)))}(d,v,f&&f.getAttribute("data-gnav-action")?f.getAttribute("data-gnav-action"):"nav")}},function(){var t;try{t=u(i.Yy,i.Lj),window[i.l9]=window[i.l9]||{},document.querySelector(i.eU).addEventListener("click",d,!0),l(t)}catch(n){l(t),function(t,n){var e=a(function(t,n){return{logType:t.jsErrorLogType,lth:t.jsErrorLth,toString:n.toString(),message:n.message,stack:n.stack,name:n.name}}(t,n)),o=t.logRoute+e;c(o)}(t,n)}}()}();</script>,
#  <script> window.addEventListener('DOMContentLoaded', function(e) { ["https://d3fw5vlhllyvee.cloudfront.net/dist/a11344fb1fbcb939e703/scripts/desktop_jobseeker_footer_external.js"].forEach(function(p) { var s = document.createElement('script'); s.src = p; document.body.appendChild(s); }) }); </script>,
#  <script type="text/javascript">
#          PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
#          PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 1, 'acmeTest', 'true', 3];
#      </script>,
#  <script type="text/javascript">
#          PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
#          PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
#      </script>,
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-8232301"></script>,
#  <script>
#              window.dataLayer = window.dataLayer || [];
#              function gtag(){dataLayer.push(arguments);}
#              gtag('js', new Date());
#              gtag('config', 'DC-8232301');
#          </script>,
#  <script type="text/javascript">
#              var ga_domains = [];
#                  ga_domains.push('indeed.co.in');
#                  ga_domains.push('indeed.lu');
#                  ga_domains.push('indeed.fr');
#                  ga_domains.push('indeed.com.br');
#                  ga_domains.push('indeed.de');
#                  ga_domains.push('indeed.co.uk');
#                  ga_domains.push('indeed.hk');
#                  ga_domains.push('indeed.fi');
#                  ga_domains.push('indeed.pt');
#                  ga_domains.push('indeed.jp');
#                  ga_domains.push('indeed.com');
#                  ga_domains.push('indeed.com.sg');
#                  ga_domains.push('indeed.nl');
#                  ga_domains.push('indeed.com.pk');
#                  ga_domains.push('indeed.cl');
#                  ga_domains.push('indeed.es');
#                  ga_domains.push('indeed.co.ve');
#                  ga_domains.push('indeed.com.mx');
#                  ga_domains.push('indeed.ae');
#                  ga_domains.push('indeed.ch');
#                  ga_domains.push('indeed.com.co');
#                  ga_domains.push('indeed.com.my');
#                  ga_domains.push('indeed.com.ph');
#                  ga_domains.push('indeed.co.za');
#                  ga_domains.push('indeed.ie');
#                  ga_domains.push('indeed.com.au');
#                  ga_domains.push('indeed.ca');
#                  ga_domains.push('indeed.com.pe');
#              (function (i, s, o, g, r, a, m) {
#                  i['GoogleAnalyticsObject'] = r;
#                  i[r] = i[r] || function () {
#                      (i[r].q = i[r].q || []).push(arguments)
#                  }, i[r].l = 1 * new Date();
#                  a = s.createElement(o),
#                          m = s.getElementsByTagName(o)[0];
#                  a.async = 1;
#                  a.src = g;
#                  m.parentNode.insertBefore(a, m)
#              })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#              var ga = ga || [];
#              ga('create', 'UA-90780-1', 'auto', {
#                  'allowLinker': true
#              });
#              ga('require', 'linkid');
#              ga('require', 'linker');
#              ga('linker:autoLink', ga_domains, false, true);
#              ga('require', 'displayfeatures');
#              ga('send', 'pageview');
#
#
#              (function () {
#                  if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
#                      for (var i in PENDING_ANALYTICS_VARS) {
#                          ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
#                      }
#                  }
#              })();
#          </script>,
#  <script>
#              window._comscore = window._comscore || [];
#              window._comscore.push({ c1: "2", c2: "6486505", c4:"br.indeed.com/cmp/Aec-Centro-De-Contatos", c15:"1f8e87utjn550801" });
#              (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#          </script>]

# %%
len(soup.findAll('script'))
# Out:
# 34

# %%
soup.findAll('script')[16]
# Out:
# <script>
#     window._initialData=JSON.parse('{"aboutSectionViewModel":{"aboutCompany":{"description":"Fortalecer vocações, a nossa vocação.\\r\\n \\r\\nPara a AeC, toda empresa possui uma vocação.\\r\\n\\r\\nBancos operam finanças. Telefônicas conectam pessoas. Hospitais cuidam\\r\\n da vida.\\r\\n\\r\\nA vocação da AeC é fortalecer vocações.\\r\\n\\r\\nE isso ela faz quando traz para si a responsabilidade por uma série de serviços\\r\\n fundamentais a vários negócios, mas que não fazem parte de seus objetivos\\r\\n principais.\\r\\n\\r\\nOutsourcing, como se diz.\\r\\n\\r\\n É o que a gente faz.\\r\\n\\r\\n E que contribui para que diversas empresas foquem em prestar serviços cada vez melhores para milhões de pessoas.\\r\\n\\r\\nInclusive você.\\r\\n","industry":"Serviços de manutenção, reparação e construção","name":"AeC Centro de Contatos"}},"baseUrl":"/cmp/Aec-Centro-De-Contatos","breadcrumbs":{"breadcrumbs":[{"name":"Empresas","noFollow":false,"url":"https://br.indeed.com/companies"},{"name":"AeC Centro de Contatos","noFollow":false}]},"companyName":"AeC Centro de Contatos","companyPageFooter":{"enabledToShowUserFeedbackForm":false,"encodedFccId":"b1f404fb53e3b248","stickyJobsTabLink":{"jobsLink":"/cmp/Aec-Centro-De-Contatos/jobs"}},"companyPageHeader":{"brandColor":"#00B5E2","companyHeader":{"name":"AeC Centro de Contatos","rating":3.9,"reviewCount":3578,"reviewCountFormatted":"3.578","reviewsUrl":"/cmp/Aec-Centro-De-Contatos/reviews","showClaimedProfile":false,"victoryHeader":false},"followButton":{"brandColor":"#00B5E2","compactType":-1,"companyName":"AeC Centro de Contatos","disclaimerRequired":false,"encodedFccId":"b1f404fb53e3b248","followSource":"acmeSnapshot","hashedCsrfToken":"7a7a8c0ff0453c1bf89150a99ab31daa","loggedIn":false},"headerImage":{"headerImageUrl":"https://d2q79iu7y748jz.cloudfront.net/s/_headerimage/c62ee8cf811ff73eb5d97dcc153e38c4","pageLanguage":"pt"},"headerVideoUrl":"","logoUrl":"https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/3a1354c8eab738988cd8eb5611158224","navMenuA11y":false,"showPremiumHeader":false,"simpleStickyHeader":false,"tabMenu":[{"name":"Visão Geral","nofollow":false,"selected":true,"turnstileElement":"overview-tab","url":"/cmp/Aec-Centro-De-Contatos"},{"name":"Junte-se a nós","nofollow":false,"selected":false,"turnstileElement":"about-tab","url":"/cmp/Aec-Centro-De-Contatos/about"},{"count":"3.578","name":"Avaliações","nofollow":false,"selected":false,"turnstileElement":"reviews-tab","url":"/cmp/Aec-Centro-De-Contatos/reviews"},{"count":"282","name":"Salários","nofollow":false,"selected":false,"turnstileElement":"salaries-tab","url":"/cmp/Aec-Centro-De-Contatos/salaries"},{"count":"49","name":"Fotos","nofollow":false,"selected":false,"turnstileElement":"photos-tab","url":"/cmp/Aec-Centro-De-Contatos/photos"},{"count":"24","name":"Empregos","nofollow":false,"selected":false,"turnstileElement":"jobs-tab","url":"/cmp/Aec-Centro-De-Contatos/jobs"},{"count":"109","name":"Perguntas","nofollow":false,"selected":false,"turnstileElement":"qna-tab","url":"/cmp/Aec-Centro-De-Contatos/faq"},{"name":"Entrevistas","nofollow":true,"selected":false,"turnstileElement":"interviews-tab","url":"/cmp/Aec-Centro-De-Contatos/interviews"}]},"encodedFccId":"b1f404fb53e3b248","interviewsSectionViewModel":{"formattedCount":"1.485","interviewQuestions":{"answers":[{"answerText":{"text":"Disponibilidade de horário, interesses profissionais."},"jobTitle":"Artífice","location":"Governador Valadares, MG","submissionDate":"24 de Junho de 2019"},{"answerText":{"text":"Gosta de trabalhar dialogando com pessoas"},"jobTitle":"Operador de Telemarketing Ativo","location":"Belo Horizonte, MG","submissionDate":"26 de Março de 2019"},{"answerText":{"text":"Como venderiam um produto fora do comercio."},"jobTitle":"Atendente De Telemarketing","location":"Belo Horizonte, MG","submissionDate":"28 de Janeiro de 2019"}],"companyName":"AeC Centro de Contatos","interviewQuestionURL":"/cmp/Aec-Centro-De-Contatos/faq/quais-perguntas-s%C3 ...
# </script>

# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
import csv
from random import randint
from datetime import date
from time import sleep
import datetime
import time
import csv

from bs4 import BeautifulSoup
import requests
import csv


def re_scraping():
    
    dados_infojobs = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    for link in df_list_url:
        cada_link = link

        try:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            time.sleep(2)    
            r = requests.get(cada_link,allow_redirects=False)
            
            if r.status_code == 200:
                print(link)
                soup = BeautifulSoup(re, "html.parser")
                try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                    conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
                except:
                    conteudo = 'None'  
                try:   
                    exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    exigencias = 'None' 
                try:
                    beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    beneficios = 'None'
                dados = {'conteudo':conteudo,
                    'exigencias':exigencias,
                    'beneficios':beneficios,
                    'url':link}
                dados_infojobs.append(dados)
                df = pd.DataFrame(dados_infojobs)
                df.to_csv('dados_infojobs.csv')
            else:
                print('url nao existe mais')
            
        except:
            re = requests.get(cada_link,allow_redirects=False, headers=headers,timeout=200).text
            time.sleep(2)    
            r = requests.get(cada_link,allow_redirects=False)
             
            if r.status_code == 200:
                print(link)
                soup = BeautifulSoup(re, "html.parser")
                try:
                #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                    conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
                except:
                    conteudo = 'None'  
                try:   
                    exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    exigencias = 'None' 
                try:
                    beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
                except:
                    beneficios = 'None'
                dados = {'conteudo':conteudo,
                    'exigencias':exigencias,
                    'beneficios':beneficios,
                    'url':link}
                dados_infojobs.append(dados)
                df = pd.DataFrame(dados_infojobs)
                df.to_csv('dados_infojobs.csv')
            else:
                print('url nao existe mais')
                
                
            
    return cada_link
                            
if __name__ == '__main__':
    re_scraping() #apenas link
    #url_chosen()

# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
import csv
from random import randint
from datetime import date
from time import sleep
import datetime
import time
import csv

from bs4 import BeautifulSoup
import requests
import csv


import aiohttp
import asyncio

# %%
#!pip install nest-asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest-asyncio in c:\users\zng-lenovo\anaconda3\envs\myenv\lib\site-packages (1.5.1)

# %%
#!pip3 install aiohttp

# %%
df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
df_list_url = df['url'].to_list()
for link in df_list_url:
    cada_link = link

# %%
cada_link
# Out:
# 'https://www.infojobs.com.br/vaga-de-auxiliar-operacoes-logistica-reposicao-centro-em-sao-paulo__7227410.aspx'

# %%
async def main():
    dados_infojobs = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
    async with aiohttp.ClientSession(headers=headers) as session:
        
        df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
        df_list_url = df['url'].to_list()
        
        for link in df_list_url:
        
            cada_link = link
            async with session.get(link) as response:
                print("Status:", response.status)
                print("Content-type:", response.headers['content-type'])

            
                html = await response.text()
                print("Body:", html[:15], "...")
                
                
                try:
                    soup = BeautifulSoup(html, "html.parser")
                    try:
                    #len(soup.findAll('ol',{'class':'descriptionItems'})) ==> 3                    
                        conteudo = soup.findAll('ol',{'class':'descriptionItems'})[0].getText().strip().replace('\r','').replace('\n','').strip()                  
                    except:
                        conteudo = 'None'  
                    try:   
                        exigencias = soup.findAll('ol',{'class':'descriptionItems'})[1].getText().strip().replace('\r','').replace('\n','').strip()
                    except:
                        exigencias = 'None' 
                    try:
                        beneficios = soup.findAll('ol',{'class':'descriptionItems'})[2].getText().strip().replace('\r','').replace('\n','').strip()
                    except:
                        beneficios = 'None'
                    dados = {'conteudo':conteudo,
                        'exigencias':exigencias,
                        'beneficios':beneficios,
                        'url':link}
                    dados_infojobs.append(dados)
                    df = pd.DataFrame(dados_infojobs)
                    df.to_csv('dados_infojobs_teste.csv')
                    
                except:
                    print('url nao existe mais')

# %%
asyncio.run(main())
# Out:
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# url nao existe mais
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# ...
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...
# Status: 200
# Content-type: text/html; charset=utf-8
# Body:
# <!DOCTYPE htm ...

# %%
asyncio.get_event_loop().run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-13-5776d10d15a1> in <module>
# ----> 1 asyncio.get_event_loop().run_until_complete(main())
#
# ~\Anaconda3\envs\myenv\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      68                 raise RuntimeError(
#      69                     'Event loop stopped before Future completed.')
# ---> 70             return f.result()
#      71
#      72     def _run_once(self):
#
# ~\Anaconda3\envs\myenv\lib\asyncio\tasks.py in _step(***failed resolving arguments***)
#     178                 # We use the `send` method directly, because coroutines
#     179                 # don't have `__iter__` and `__next__` methods.
# --> 180                 result = coro.send(None)
#     181             else:
#     182                 result = coro.throw(exc)
#
# <ipython-input-12-dcf19dcad9e8> in main()
#       9
#      10             cada_link = link
# ---> 11             async with session.get('cada_link') as response:
#      12                 print("Status:", response.status)
#      13                 print("Content-type:", response.headers['content-type'])
#
# ~\Anaconda3\envs\myenv\lib\site-packages\aiohttp\client.py in __aenter__(self)
#    1115
#    1116     async def __aenter__(self) -> _RetType:
# -> 1117         self._resp = await self._coro
#    1118         return self._resp
#    1119
#
# ~\Anaconda3\envs\myenv\lib\site-packages\aiohttp\client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     511                         ssl=ssl,
#     512                         proxy_headers=proxy_headers,
# --> 513                         traces=traces,
#     514                     )
#     515
#
# ~\Anaconda3\envs\myenv\lib\site-packages\aiohttp\client_reqrep.py in __init__(self, method, url, params, headers, skip_auto_headers, data, cookies, auth, version, compress, chunked, expect100, loop, response_class, proxy, proxy_auth, timer, session, ssl, proxy_headers, traces)
#     303
#     304         self.update_version(version)
# --> 305         self.update_host(url)
#     306         self.update_headers(headers)
#     307         self.update_auto_headers(skip_auto_headers)
#
# ~\Anaconda3\envs\myenv\lib\site-packages\aiohttp\client_reqrep.py in update_host(self, url)
#     364         # get host/port
#     365         if not url.raw_host:
# --> 366             raise InvalidURL(url)
#     367
#     368         # basic auth info
#
# InvalidURL: cada_link

# %%
loop = asyncio.get_event_loop()
loop.run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-81c34b4ed109> in <module>
#       1 loop = asyncio.get_event_loop()
# ----> 2 loop.run_until_complete(main())
#
# ~\Anaconda3\envs\myenv\lib\asyncio\base_events.py in run_until_complete(self, future)
#     473         future.add_done_callback(_run_until_complete_cb)
#     474         try:
# --> 475             self.run_forever()
#     476         except:
#     477             if new_task and future.done() and not future.cancelled():
#
# ~\Anaconda3\envs\myenv\lib\asyncio\base_events.py in run_forever(self)
#     427         self._check_closed()
#     428         if self.is_running():
# --> 429             raise RuntimeError('This event loop is already running')
#     430         if events._get_running_loop() is not None:
#     431             raise RuntimeError(
#
# RuntimeError: This event loop is already running

# %%
asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-eaadc83a82ea> in <module>
# ----> 1 asyncio.run(main())
#
# AttributeError: module 'asyncio' has no attribute 'run'

# %%
    dados_infojobs = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
          
    df = pd.read_csv('Infojobs_t0_consolidada_asct.csv',index_col=0)
    df_list_url = df['url'].to_list()
    for link in df_list_url:
        cada_link = link
