# %%
from lxml import html
import requests
import bs4
import json
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import time

# %%
lista = []

for i in range(1, 3):
    addresses = 'https://www.catho.com.br/vagas/cientista-de-dados/?q=Cientista%20de%20Dados&page={page_num}'.format(page_num = i) 
    print(addresses)
    chromedriver = "C:/Users/Zng/Desktop/Scrapy/chromedriver_win32/chromedriver"
    driver = webdriver.Chrome(chromedriver)
    driver.get(addresses)
    elements = driver.find_elements_by_xpath('//header[@class="Header-sc-1u94v40-0 fKYpuG"]/div[@class="HeaderText-sc-15zd9gn-0 ibKDPi"]/div[1]')
    time.sleep(2)
    print(i)
    
    for each_one in elements:
        title = each_one.find_element_by_xpath('.//h2/a').text
        list_catho = {'Job_Title' : title}
        lista.append(list_catho)
# Out:
# https://www.catho.com.br/vagas/cientista-de-dados/?q=Cientista%20de%20Dados&page=1
# 1
# https://www.catho.com.br/vagas/cientista-de-dados/?q=Cientista%20de%20Dados&page=2
# 2

# %%
lista
# Out:
# [{'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados I'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados Jr.'},
#  {'Job_Title': 'Cientista de Dados Pleno'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados Sênior'},
#  {'Job_Title': 'Engenheiro de Dados / Cientista de Dados - Sênior - DataSUS'},
#  {'Job_Title': 'Especialista em Ciência de Dados'},
#  {'Job_Title': 'Coordenador de Ciência de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
# ...

# %% [raw]
# ##############################################################################################################################################################

# %%
li = []
def oneplus():

    for i in range(1, 3):
        addresses = 'https://www.catho.com.br/vagas/cientista-de-dados/?q=Cientista%20de%20Dados&page={page_num}'.format(page_num = i) 
        print(addresses)
        chromedriver = "C:/Users/Zng/Desktop/Scrapy/chromedriver_win32/chromedriver"
        driver = webdriver.Chrome(chromedriver)
        driver.get(addresses)
        elements = driver.find_elements_by_xpath('//header[@class="Header-sc-1u94v40-0 fKYpuG"]/div[@class="HeaderText-sc-15zd9gn-0 ibKDPi"]/div[1]')
        time.sleep(2)
        print(i)
        
        for each_one in elements:
            title = each_one.find_element_by_xpath('.//h2/a').text
            list_catho = {'Job_Title' : title}
            li.append(list_catho)

# %%
oneplus()
# Out:
# https://www.catho.com.br/vagas/cientista-de-dados/?q=Cientista%20de%20Dados&page=1
# 1
# https://www.catho.com.br/vagas/cientista-de-dados/?q=Cientista%20de%20Dados&page=2
# 2

# %%
li
# Out:
# [{'Job_Title': 'Cientista de Dados I'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados Jr.'},
#  {'Job_Title': 'Cientista de Dados Pleno'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados Sênior'},
#  {'Job_Title': 'Engenheiro de Dados / Cientista de Dados - Sênior - DataSUS'},
#  {'Job_Title': 'Especialista em Ciência de Dados'},
#  {'Job_Title': 'Coordenador de Ciência de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
#  {'Job_Title': 'Cientista de Dados'},
# ...

# %% [raw]
# ##############################################################################################################################################################

# %% [raw]
# ###############################################################################
#
# BeautifulSoup with Xpath
#
# # https://qastack.com.br/programming/11465555/can-we-use-xpath-with-beautifulsoup
#
# # https://docs.python-guide.org/scenarios/scrape/
#
# ###############################################################################

# %%
from bs4 import BeautifulSoup
from lxml import html
import requests

page = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")

# %%
url = "https://www.tutorialspoint.com/index.htm"

# %%
req = requests.get(url)

# %%
soup = BeautifulSoup(req.text, "html.parser")
print(soup.title)
print("""

""")
print(soup.title.text)
# Out:
# <title>RxJS, ggplot2, Python Data Persistence, Caffe2, PyBrain, Python Data Access, H2O, Colab, Theano, Flutter, KNime, Mean.js, Weka, Solidity</title>
#
#
#
# RxJS, ggplot2, Python Data Persistence, Caffe2, PyBrain, Python Data Access, H2O, Colab, Theano, Flutter, KNime, Mean.js, Weka, Solidity

# %%
soup = BeautifulSoup(req.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="ie ie8"> <![endif]-->
# <!--[if IE 9]><html class="ie ie9"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html lang="en-US"> <!--<![endif]-->
# <head>
# <!-- Basic -->
# <meta charset="utf-8"/>
# <title>RxJS, ggplot2, Python Data Persistence, Caffe2, PyBrain, Python Data Access, H2O, Colab, Theano, Flutter, KNime, Mean.js, Weka, Solidity</title>
# <meta content="RxJS, ggplot2, Python Data Persistence, Caffe2, PyBrain, Python Data Access, H2O, Colab, Theano, Flutter, KNime, Mean.js, Weka, Solidity" name="Description">
# <meta content="RxJS, ggplot2, Python Data Persistence, Caffe2, PyBrain, Python Data Access, H2O, Colab, Theano, Flutter, KNime, Mean.js, Weka, Solidity" name="Keywords"/>
# <link href="https://www.tutorialspoint.com" rel="canonical"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.tutorialspoint.com/index.htm
# https://www.tutorialspoint.com/about/about_careers.htm
# https://www.tutorialspoint.com/questions/index.php
# https://www.tutorialspoint.com/online_dev_tools.htm
# https://www.tutorialspoint.com/codingground.htm
# https://www.tutorialspoint.com/upsc_ias_exams.htm
# https://www.tutorialspoint.com/whiteboard.htm
# https://www.tutorix.com
# https://www.tutorialspoint.com/videotutorials/login.php
# https://www.tutorialspoint.com/index.htm
# https://www.tutorialspoint.com/tutorialslibrary.htm
# https://www.tutorialspoint.com/videotutorials/index.php
# https://store.tutorialspoint.com
# https://www.tutorialspoint.com/gate_exams_tutorials.htm
# videotutorials/subscription.php
# https://www.tutorix.com/buy-activation.php
# https://www.tutorialspoint.com/videotutorials/latest-courses.php
# None
# None
# None
# None
# None
# None
# None
# https://www.tutorialspoint.com/angular_8_full_stack_development_with_spring_boot/index.asp
# ...

# %% [raw]
# ###############################################################################
#
# BeautifulSoup with Xpath
#
# # https://qastack.com.br/programming/11465555/can-we-use-xpath-with-beautifulsoup
#
# ###############################################################################

# %%
from bs4 import BeautifulSoup
# from lxml.cssselect import CSSSelector
from lxml import html
import requests

# %%
page = requests.get('http://econpy.pythonanywhere.com/ex/001.html')
tree = html.fromstring(page.content)

# %%
buyers = tree.xpath('//div[@title="buyer-name"]/text()')
buyers
# Out:
# ['Carson Busses',
#  'Earl E. Byrd',
#  'Patty Cakes',
#  'Derri Anne Connecticut',
#  'Moe Dess',
#  'Leda Doggslife',
#  'Dan Druff',
#  'Al Fresco',
#  'Ido Hoe',
#  'Howie Kisses',
#  'Len Lease',
#  'Phil Meup',
#  'Ira Pent',
#  'Ben D. Rules',
#  'Ave Sectomy',
#  'Gary Shattire',
#  'Bobbi Soks',
#  'Sheila Takya',
#  'Rose Tattoo',
#  'Moe Tell']

# %%
from time import sleep
from random import randint
Final Scraping Code:
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
from time import sleep
from random import randint
import numpy as np

headers = dict()
headers[
    "User-Agent"
] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36"

titles = []
years = []
time = []
imdb_ratings = []
genre = []
votes = []
pages = np.arange(1, 1001, 50)
for page in pages:
    url = "https://www.imdb.com/search/title/?groups=top_1000&start=" + str(page)
    results = requests.get(url, headers=headers)
    soup = BeautifulSoup(results.text, "html.parser")
    movie_div = soup.find_all("div", class_="lister-item mode-advanced")
    sleep(randint(2, 10))
    print(page)
    for movieSection in movie_div:
        name = movieSection.h3.a.text
        titles.append(name)
        year = movieSection.h3.find("span", class_="lister-item-year").text
        years.append(year)
        ratings = movieSection.strong.text
        imdb_ratings.append(ratings)
        category = movieSection.find("span", class_="genre").text.strip()
        genre.append(category)
        runTime = movieSection.find("span", class_="runtime").text
        time.append(runTime)
        nv = movieSection.find_all("span", attrs={"name": "nv"})
        vote = nv[0].text
        votes.append(vote)
movies = pd.DataFrame(
    {
        "Movie": titles,
        "Year": years,
        "RunTime": time,
        "imdb": imdb_ratings,
        "Genre": genre,
        "votes": votes,
    }
)

# cleaning
movies["Year"] = movies["Year"].str.extract("(\\d+)").astype(int)
movies["RunTime"] = movies["RunTime"].str.replace("min", "minutes")
movies["votes"] = movies["votes"].str.replace(",", "").astype(int)

print(movies)
movies.to_csv(r"C:\Users\Aleti Sunil\Downloads\movies.csv", index=False, header=True)

# %%
# https://dev.to/sunilaleti/webscraping-part-2-445
